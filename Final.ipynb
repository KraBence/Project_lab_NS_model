# %% [markdown]
# # Dynamic Nelson Siegel model implementation

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from statsmodels.tsa.statespace.mlemodel import MLEModel
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import warnings

# Load data
df = pd.read_excel('NS_adatok_cln.xlsx')
rename_dict = {
    'DATE': 'Date',
    'M0.033': 'M0.033',
    'M1': 'M1',
    'M3': 'M3',
    'M6': 'M6',
    'M12': 'M12',
    'M36': 'M36',
    'M60': 'M60',
    'M120': 'M120',
    'M180': 'M180',
    'Kamat': 'Base_Rate',
    'Árfolyam': 'Exchange_Rate',
    'GDP': 'GDP',
    'Végső fogyasztás': 'Final_Consumption',
    'Export': 'Export',
    'Kockázati prémium': 'Risk_Premium',
    'Külső kamat': 'External_Interest_Rate',
    'Privát foglalkoztatott': 'Private_Employment',
    'Teljes állami létszám': 'Total_Public_Employment',
    'Közmunkások': 'Public_Work_Participants',
    'Állami létszám közfoglalkoztatottak nélkül': 'Public_Employment_Excl_Public_Work',
    'Infláció': 'Inflation',
    'Importár': 'Import_Price',
    'Háztartások rendelkezésre álló jövedelme': 'Household_Disposable_Income',
    'Háztartások rendelkezésre álló jövedelme (2015)': 'Household_Disposable_Income_2015',
    'Háztartások megtakarítása': 'Household_Savings'
}
df.rename(columns=rename_dict, inplace=True)
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)

yield_cols = ['M0.033', 'M1', 'M3', 'M6', 'M12', 'M36', 'M60', 'M120', 'M180']
maturities = np.array([0.033, 1, 3, 6, 12, 36, 60, 120, 180]) / 12.0
lam_fixed = 0.7308

data_clean = df[yield_cols].copy()
data_clean['Base_Rate'] = df['Base_Rate']
data_clean['Inflation'] = df['Inflation']
data_clean['GDP_Growth'] = df['GDP'].pct_change() * 100
data_clean['FX_Change'] = df['Exchange_Rate'].pct_change() * 100
data_clean = data_clean.dropna()

scaler = StandardScaler()
macro_cols = ['Base_Rate', 'Inflation', 'GDP_Growth', 'FX_Change']
data_clean[macro_cols] = scaler.fit_transform(data_clean[macro_cols])

def get_ns_loadings(tau, lam, factors=3):
    l1 = np.ones_like(tau)
    l2 = (1 - np.exp(-lam * tau)) / (lam * tau)
    if factors == 3:
        l3 = l2 - np.exp(-lam * tau)
        return np.column_stack([l1, l2, l3])
    return np.column_stack([l1, l2])

class RobustDNS(MLEModel):
    def __init__(self, endog, maturities, n_ns_factors, lam=0.7308):
        k_states = n_ns_factors + 4
        super(RobustDNS, self).__init__(endog, k_states=k_states, k_posdef=k_states)
        self.n_ns = n_ns_factors
        self.n = k_states
        self.ssm['design', :len(maturities), :n_ns_factors] = get_ns_loadings(maturities, lam, n_ns_factors)
        self.ssm['design', len(maturities):, n_ns_factors:] = np.eye(4)
        self.ssm['selection'] = np.eye(k_states)
        self.initialize_approximate_diffuse()

    def update(self, params, **kwargs):
        params = super(RobustDNS, self).update(params, **kwargs)
        n = self.n
        idx = 0
        transition_flat = params[idx : idx + n**2]
        self.ssm['transition', :, :] = np.tanh(transition_flat).reshape(n, n)
        idx += n**2
        for i in range(n):
            self.ssm['state_cov', i, i] = np.exp(params[idx])
            idx += 1
        for i in range(self.k_endog):
            self.ssm['obs_cov', i, i] = np.exp(params[idx])
            idx += 1

    @property
    def start_params(self):
        n = self.n
        t_start = np.eye(n) * 0.8
        t_start_flat = t_start.flatten()
        q_start = [-2.0] * n
        r_start = [-3.0] * self.k_endog
        return np.concatenate([t_start_flat, q_start, r_start])

# OLS estimations
reg = LinearRegression(fit_intercept=False)
ols_3f_res, ols_2f_res = [], []
for i in range(len(data_clean)):
    y = data_clean[yield_cols].iloc[i].values
    ols_3f_res.append(reg.fit(get_ns_loadings(maturities, lam_fixed, 3), y).coef_)
    ols_2f_res.append(reg.fit(get_ns_loadings(maturities, lam_fixed, 2), y).coef_)

ols_3f = pd.DataFrame(ols_3f_res, index=data_clean.index, columns=['Level', 'Slope', 'Curvature'])
ols_2f = pd.DataFrame(ols_2f_res, index=data_clean.index, columns=['Level', 'Slope'])

# Run models
endog_data = data_clean[yield_cols + macro_cols]

# Fit 3F Kalman (VAR)
model3f = RobustDNS(endog_data, maturities, 3)
res3f = model3f.fit(disp=False, maxiter=200)
kf3_f = pd.DataFrame(res3f.smoothed_state[:3, :].T, index=data_clean.index, columns=['Level', 'Slope', 'Curvature'])

# Fit 2F Kalman (VAR)
model2f = RobustDNS(endog_data, maturities, 2)
res2f = model2f.fit(disp=False, maxiter=200)
kf2_f = pd.DataFrame(res2f.smoothed_state[:2, :].T, index=data_clean.index, columns=['Level', 'Slope'])
# Out:
# /home/bence/PycharmProjects/Project_lab/.venv/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
# /home/bence/PycharmProjects/Project_lab/.venv/lib/python3.12/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/bence/PycharmProjects/Project_lab/.venv/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
# /home/bence/PycharmProjects/Project_lab/.venv/lib/python3.12/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
# RMSE Comparison
def get_rmse(obs, est, f):
    recon = est @ get_ns_loadings(maturities, lam_fixed, f).T
    return np.sqrt(((obs.values - recon.values)**2).mean())

rmse_stats = {
    "OLS 3F": get_rmse(data_clean[yield_cols], ols_3f, 3),
    "OLS 2F": get_rmse(data_clean[yield_cols], ols_2f, 2),
    "Kalman 3F (VAR)": get_rmse(data_clean[yield_cols], kf3_f, 3),
    "Kalman 2F (VAR)": get_rmse(data_clean[yield_cols], kf2_f, 2)
}

# Plot 1: Factor Comparison
plt.figure(figsize=(14, 10))
plt.subplot(3, 1, 1)
plt.plot(ols_3f['Level'], label='OLS 3F', color='black', linestyle='--')
plt.plot(ols_2f['Level'], label='OLS 2F', color='black', linestyle='dotted', alpha=0.6)
plt.plot(kf3_f['Level'], label='Kalman 3F (VAR)', color='blue', alpha=0.7)
plt.plot(kf2_f['Level'], label='Kalman 2F (VAR)', color='red', alpha=0.7)
plt.title('LEVEL Factor Comparison (VAR transition matrix)')
plt.legend()

plt.subplot(3, 1, 2)
plt.plot(ols_3f['Slope'], label='OLS 3F', color='black', linestyle='--')
plt.plot(ols_2f['Slope'], label='OLS 2F', color='black', linestyle='dotted', alpha=0.6)
plt.plot(kf3_f['Slope'], label='Kalman 3F (VAR)', color='cyan', alpha=0.7)
plt.plot(kf2_f['Slope'], label='Kalman 2F (VAR)', color='orange', alpha=0.7)
plt.title('SLOPE Factor Comparison (VAR transition matrix)')
plt.legend()
plt.tight_layout()
#plt.savefig('factor_comparison.png')

# 3. Grafikon: CURVATURE (Görbület)
# Megjegyzés: Csak a 3-faktoros modellek rendelkeznek görbülettel
plt.subplot(3, 1, 3)
plt.plot(ols_3f['Curvature'], label='OLS 3F', color='black', linestyle='--', alpha=0.7)
plt.plot(kf3_f['Curvature'], label='Kalman 3F (VAR)', color='red', alpha=0.7, linewidth=2)
plt.axhline(0, color='black', linewidth=0.5, alpha=0.5) # Nulla vonal a tájékozódáshoz
plt.title('CURVATURE Factor Comparison (3-Factor Models Only)')
plt.legend()

# Plot 2: Selected Curves
sample_idx = [0, len(data_clean)//2, -1]
plt.figure(figsize=(15, 5))
for i, idx in enumerate(sample_idx):
    date = data_clean.index[idx]
    plt.subplot(1, 3, i+1)
    plt.scatter(maturities, data_clean.iloc[idx][yield_cols], color='black', label='Actual')

    # 3F Reconstruction
    recon3f = kf3_f.iloc[idx].values @ get_ns_loadings(maturities, lam_fixed, 3).T
    plt.plot(maturities, recon3f, label='Kalman 3F', color='blue')

    # 2F Reconstruction
    recon2f = kf2_f.iloc[idx].values @ get_ns_loadings(maturities, lam_fixed, 2).T
    plt.plot(maturities, recon2f, label='Kalman 2F', color='red', linestyle='--')

    plt.title(f'Yield Curve: {date.date()}')
    plt.legend()
plt.tight_layout()
plt.savefig('curve_fitting.png')

print(rmse_stats)
# Out:
# {'OLS 3F': np.float64(0.19179796405346092), 'OLS 2F': np.float64(0.3396735308864125), 'Kalman 3F (VAR)': np.float64(0.24000321808430267), 'Kalman 2F (VAR)': np.float64(0.3817838427032546)}

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

def plot_models_on_date(target_date_str, data_obs, maturities_obs, models_dict, lam):
    """
    Kiplottolja a tényleges hozamokat és a 4 modell illesztését egy adott napra.
    models_dict: {'Modell neve': (faktor_df, n_factors)}
    """
    # 1. Dátum kezelése (legközelebbi elérhető index kiválasztása)
    target_date = pd.to_datetime(target_date_str)
    available_dates = data_obs.index
    actual_date = available_dates[np.argmin(np.abs(available_dates - target_date))]

    print(f"Cél dátum: {target_date_str} | Felhasznált adat: {actual_date.date()}")

    # 2. Sima görbe rajzolásához lejárati tartomány (0.1 - 15 év)
    maturities_smooth = np.linspace(0.01, 15, 100)

    plt.figure(figsize=(12, 7))

    # 3. Tényleges piaci adatok (fekete pontok)
    actual_yields = data_obs.loc[actual_date, yield_cols].values
    plt.scatter(maturities_obs, actual_yields, color='black', s=50, label='Market data (observed)', zorder=5)

    # 4. Modellek futtatása a kiválasztott napra
    colors = {'OLS 3F': 'green', 'Kalman 3F (VAR)': 'blue', 'OLS 2F': 'orange', 'Kalman 2F (VAR)': 'red'}
    linestyles = {'OLS 3F': '--', 'Kalman 3F (VAR)': '-', 'OLS 2F': '--', 'Kalman 2F (VAR)': '-'}

    for name, (factor_df, n_f) in models_dict.items():
        # Faktorok kinyerése az adott napra
        factors = factor_df.loc[actual_date].values

        # Elméleti hozamok számítása a sima görbéhez
        L_smooth = get_ns_loadings(maturities_smooth, lam, n_f)
        fitted_curve = L_smooth @ factors

        plt.plot(maturities_smooth, fitted_curve,
                 label=name, color=colors[name],
                 linestyle=linestyles[name], linewidth=2)

    # 5. Formázás
    plt.title(f'Estimated Yield curve({actual_date.date()})', fontsize=14)
    plt.xlabel('Maturity (Year)', fontsize=12)
    plt.ylabel('Yield (%)', fontsize=12)
    plt.legend(fontsize=10)
    plt.grid(True, alpha=0.3)
    plt.ylim(min(actual_yields)-0.5, max(actual_yields)+0.5)
    plt.show()

# --- HASZNÁLAT ---

# 1. Regisztráljuk a már korábban kiszámított modell-faktorokat
# Feltételezzük, hogy kf3_f, kf2_f, ols_3f, ols_2f változók léteznek a memóriában
all_models = {
    'OLS 3F': (ols_3f, 3),
    'Kalman 3F (VAR)': (kf3_f, 3),
    'OLS 2F': (ols_2f, 2),
    'Kalman 2F (VAR)': (kf2_f, 2)
}

# 2. Futtatás a kért dátumra
plot_models_on_date('2024-07-01', data_clean, maturities, all_models, lam_fixed)
# Out:
# Cél dátum: 2024-07-01 | Felhasznált adat: 2024-07-01

# %%
# --- PARAMÉTEREK ÉS STABILITÁS ELLENŐRZÉSE ---

def analyze_stability(results, name):
    # 1. Átmeneti mátrix (T) kinyerése
    T = results.model.ssm['transition', :, :, 0]

    # 2. Sajátértékek vizsgálata (Stabilitás feltétele: minden sajátérték < 1)
    eigenvalues = np.linalg.eigvals(T)
    max_eig = np.abs(eigenvalues).max()

    # 3. Varianciák (Q: folyamatzaj, R: mérési zaj)
    # Átlagos mérési hiba (R mátrix főátlója)
    avg_obs_error = np.sqrt(np.diag(results.model.ssm['obs_cov', :, :, 0])).mean()
    # Átlagos állapot-bizonytalanság (Q mátrix főátlója)
    avg_state_innov = np.sqrt(np.diag(results.model.ssm['state_cov', :, :, 0])).mean()

    print(f"\n--- {name} Elemzése ---")
    print(f"Max sajátérték (Stabilitás < 1): {max_eig:.4f}")
    print(f"Átlagos mérési bizonytalanság (R): {avg_obs_error:.4f}%")
    print(f"Átlagos faktor-ingadozás (Q): {avg_state_innov:.4f}")
    print(f"AIC érték (Kisebb a jobb): {results.aic:.2f}")

# Futtassuk le mindkét Kalman modellre
analyze_stability(res3f, "Kalman 3-Faktor (VAR)")
analyze_stability(res2f, "Kalman 2-Faktor (VAR)")
# Out:
# --- Kalman 3-Faktor (VAR) Elemzése ---
# Max sajátérték (Stabilitás < 1): 0.9917
# Átlagos mérési bizonytalanság (R): 0.2614%
# Átlagos faktor-ingadozás (Q): 0.4660
# AIC érték (Kisebb a jobb): 630.37
#
# --- Kalman 2-Faktor (VAR) Elemzése ---
# Max sajátérték (Stabilitás < 1): 0.9925
# Átlagos mérési bizonytalanság (R): 0.3429%
# Átlagos faktor-ingadozás (Q): 0.3667
# AIC érték (Kisebb a jobb): 1009.66

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# --- REZIDUÁLIS ELEMZÉS FUNKCIÓ ---
def analyze_residuals_all(observed_yields, estimated_factors, maturities, lam, n_factors):
    # Nelson-Siegel loading mátrix (Z) generálása
    L = get_ns_loadings(maturities, lam, n_factors)

    # Hozamok rekonstruálása: Y = Faktorok @ L.T
    reconstructed = estimated_factors.values @ L.T
    reconstructed_df = pd.DataFrame(reconstructed, index=observed_yields.index, columns=observed_yields.columns)

    # Hibák (Reziduálisok) = Megfigyelt - Rekonstruált
    residuals = observed_yields - reconstructed_df

    # RMSE (Root Mean Square Error) kiszámítása lejáratonként
    rmse_per_maturity = np.sqrt((residuals**2).mean())
    return rmse_per_maturity

# --- SZÁMÍTÁSOK ---
rmse_ols3 = analyze_residuals_all(data_clean[yield_cols], ols_3f, maturities, lam_fixed, 3)
rmse_kf3  = analyze_residuals_all(data_clean[yield_cols], kf3_f, maturities, lam_fixed, 3)
rmse_ols2 = analyze_residuals_all(data_clean[yield_cols], ols_2f, maturities, lam_fixed, 2)
rmse_kf2  = analyze_residuals_all(data_clean[yield_cols], kf2_f, maturities, lam_fixed, 2)

# Összegzés megjelenítése
print(f"Átlagos RMSE - OLS 3F:    {rmse_ols3.mean():.4f}%")
print(f"Átlagos RMSE - Kalman 3F: {rmse_kf3.mean():.4f}%")
print(f"Átlagos RMSE - OLS 2F:    {rmse_ols2.mean():.4f}%")
print(f"Átlagos RMSE - Kalman 2F: {rmse_kf2.mean():.4f}%")

# Vizualizáció (Lejáratonkénti hiba)
plt.figure(figsize=(12, 6))
plt.plot(maturities, rmse_ols3, label='OLS 3F', marker='o', color='green')
plt.plot(maturities, rmse_ols2, label='OLS 2F', marker='x', color='grey')
plt.plot(maturities, rmse_kf3, label='Kalman 3F (VAR)', marker='s', color='blue')
plt.plot(maturities, rmse_kf2, label='Kalman 2F (VAR)', marker='v', color='red')
plt.title('Yield curve fitting error (RMSE)')
plt.xlabel('Maturity (Year)')
plt.ylabel('RMSE (%)')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# Átlagos RMSE - OLS 3F:    0.1834%
# Átlagos RMSE - Kalman 3F: 0.1881%
# Átlagos RMSE - OLS 2F:    0.3199%
# Átlagos RMSE - Kalman 2F: 0.3277%

# %%
def get_res_and_rmse(obs, est, n_factors):
    L = get_ns_loadings(maturities, lam_fixed, n_factors)
    recon = pd.DataFrame(est.values @ L.T, index=obs.index, columns=obs.columns)
    residuals = obs - recon
    rmse = np.sqrt((residuals**2).mean())
    return residuals, rmse

res_kf3, rmse_kf3 = get_res_and_rmse(data_clean[yield_cols], kf3_f, 3)
res_kf2, rmse_kf2 = get_res_and_rmse(data_clean[yield_cols], kf2_f, 2)
res_ols3, rmse_ols3 = get_res_and_rmse(data_clean[yield_cols], ols_3f, 3)
res_ols2, rmse_ols2 = get_res_and_rmse(data_clean[yield_cols], ols_2f, 2)
rmse_comparison = pd.DataFrame({
    'OLS 3F': rmse_ols3,
    'Kalman 3F': rmse_kf3,
    'OLS 2F': rmse_ols2,
    'Kalman 2F': rmse_kf2
})

# --- 5. SPECIÁLIS VIZUALIZÁCIÓ ---
plt.figure(figsize=(14, 10))

# 1. Grafikon: Átlagos hiba lejáratonként (Bar chart)
plt.subplot(2, 2, 1)
rmse_comparison.plot(kind='bar', ax=plt.gca(), color=['green', 'blue', 'grey', 'red'])
plt.title('Average error (RMSE) by maturities')
plt.ylabel('Error (%)')
plt.grid(axis='y', alpha=0.3)

# 2. Grafikon: Reziduálisok eloszlása (Boxplot)
plt.subplot(2, 2, 2)
res_kf3.boxplot(ax=plt.gca())
plt.title('Distribution of the error of 3F Kalman (VAR)')
plt.xticks(rotation=45)
plt.grid(alpha=0.3)

# 3. Grafikon: Hiba időbeli alakulása (10 év - M120)
plt.subplot(2, 1, 2)
plt.plot(res_ols3['M120'], label='OLS 3F (10Y) error', alpha=0.5, color='green')
plt.plot(res_kf3['M120'], label='Kalman 3F (10Y) error', color='blue', linewidth=1.5)
plt.axhline(0, color='black', linestyle='--', linewidth=1)
plt.title('Estimation error of the 10-year yield (M120) over time')
plt.legend()
plt.grid(alpha=0.3)

plt.tight_layout()
plt.show()

# Összesített statisztika kiírása
print("\n--- Full average RMSE ---")
print(rmse_comparison.mean())
# Out:
# --- Full average RMSE ---
# OLS 3F       0.183404
# Kalman 3F    0.188084
# OLS 2F       0.319903
# Kalman 2F    0.327680
# dtype: float64

# %%
# --- 1. PARAMÉTEREK ÉS ÁTMENETI MÁTRIX KINYERÉSE ---
# Közvetlenül a modell ssm (state space model) objektumából
T_matrix = res3f.model.ssm['transition', :, :, 0]
state_names = ['Level', 'Slope', 'Curvature', 'Base_Rate', 'Inflation', 'GDP_Growth', 'FX_Change']

import seaborn as sns
plt.figure(figsize=(10, 8))
sns.heatmap(T_matrix, annot=True, xticklabels=state_names, yticklabels=state_names, cmap='RdBu_r', center=0)
plt.title("Optimized Transition Matrix (T) - Interactions")
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf  # <--- Direct import fixed here

# 1. Extract all factors from the smoothed state
# (Assuming 'res3f' and 'data_clean' are already defined in your notebook)
state_names = ['Level', 'Slope', 'Curvature', 'Base_Rate', 'Inflation', 'GDP_Growth', 'FX_Change']
all_factors = pd.DataFrame(res3f.smoothed_state.T, index=data_clean.index, columns=state_names)

# 2. Setup the plot grid (4 rows, 2 columns for 7 factors)
fig, axes = plt.subplots(4, 2, figsize=(15, 20))
fig.suptitle('Autocorrelation of Latent and Macro Factors', fontsize=20)

axes = axes.flatten()

# 3. Loop through factors and plot ACF
for i, col in enumerate(state_names):
    # Using the directly imported plot_acf function
    plot_acf(all_factors[col], ax=axes[i], lags=20, title=f'ACF: {col}')
    axes[i].set_xlabel('Lags')
    axes[i].set_ylabel('Autocorrelation')

# Remove the empty 8th subplot
fig.delaxes(axes[7])

plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.show()

# %%
# Fit 3F Kalman (VAR)
endog_data = data_clean[yield_cols + macro_cols]
model3f = RobustDNS(endog_data, maturities, 3)
res3f = model3f.fit(disp=False, maxiter=300)

# Extract Transition Matrix
T_matrix_raw = res3f.model.ssm['transition', :, :, 0]
state_names = ['Level', 'Slope', 'Curvature', 'Base_Rate', 'Inflation', 'GDP_Growth', 'FX_Change']
T_df = pd.DataFrame(T_matrix_raw, index=state_names, columns=state_names)

# Extract diagonal of Q (state variances)
Q_diag = np.diag(res3f.model.ssm['state_cov', :, :, 0])
Q_df = pd.DataFrame(Q_diag, index=state_names, columns=['State_Variance'])

# Extract diagonal of R (observation variances) - average over yields
R_diag = np.diag(res3f.model.ssm['obs_cov', :, :, 0])
R_yields_avg = np.sqrt(R_diag[:len(yield_cols)]).mean()
R_macro_avg = np.sqrt(R_diag[len(yield_cols):]).mean()

# Cross-effects: Macro -> Yield Factors
cross_effects = T_df.loc[['Level', 'Slope', 'Curvature'], ['Base_Rate', 'Inflation', 'GDP_Growth', 'FX_Change']]

print("Transition Matrix:\n", T_df)
print("\nCross Effects (Macro -> Factors):\n", cross_effects)
print("\nState Variances (Q):\n", Q_df)
print("\nAverage Observation RMSE Yields (R):", R_yields_avg)
cross_effects.to_csv('macro_factor_relations.csv')
# Out:
# /home/bence/PycharmProjects/Project_lab/.venv/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
# Transition Matrix:
#                 Level     Slope  Curvature  Base_Rate  Inflation  GDP_Growth  \
# Level       0.999271  0.011001   0.037609  -0.192762   0.199358    0.137643
# Slope      -0.002147  0.621088   0.121420   0.136561   0.890634   -0.204091
# Curvature  -0.056815 -0.194256   0.975449   0.414207  -0.193019    0.645027
# Base_Rate   0.005511 -0.052680   0.047069   0.905307   0.150089    0.103677
# Inflation   0.035533 -0.011758   0.114111  -0.298904   0.954366    0.055797
# GDP_Growth -0.005502  0.029557  -0.048059  -0.247404   0.077641   -0.390383
# FX_Change  -0.005761  0.067367  -0.013426  -0.180003  -0.012572    0.492057
#
#             FX_Change
# Level        0.436285
# Slope       -0.231133
# Curvature    0.946858
# Base_Rate    0.189382
# Inflation    0.227041
# GDP_Growth  -0.163283
# FX_Change    0.416598
#
# Cross Effects (Macro -> Factors):
#             Base_Rate  Inflation  GDP_Growth  FX_Change
# Level      -0.192762   0.199358    0.137643   0.436285
# Slope       0.136561   0.890634   -0.204091  -0.231133
# Curvature   0.414207  -0.193019    0.645027   0.946858
#
# State Variances (Q):
#              State_Variance
# Level             0.081768
# Slope             0.315404
# Curvature         0.815711
# Base_Rate         0.003683
# Inflation         0.025522
# GDP_Growth        0.504359
# FX_Change         0.335886
#
# Average Observation RMSE Yields (R): 0.2073469759294141
# /home/bence/PycharmProjects/Project_lab/.venv/lib/python3.12/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
from scipy.linalg import qr, cholesky

warnings.filterwarnings("ignore")

# ==========================================
# KONFIGURÁCIÓS PARAMÉTEREK
# ==========================================
N_SUCCESSFUL_SAMPLES = 5000  # Itt állítsd be a kívánt sikeres minták számát
IRF_STEPS = 25               # Hány negyedévre nézzük a hatást
CONFIDENCE_INTERVAL = [16, 84] # Reppa (2009) alapján 1 szórásnyi sáv
res = res3f
# --- 1. REPPA-FÉLE ELŐJEL-MEGKÖTÉSEK (Table 6) ---
def check_reppa_signs_old(S_column, shock_type):
    # Állapotvektor indexek: 3:Base_Rate, 4:Inflation, 5:GDP_Growth, 6:FX_Change
    if shock_type == 'PREM':
        # Kockázati prémium: Kamat emelkedik (+), Forint gyengül (FX_Change > 0)
        return S_column[3] > 0 and S_column[6] > 0
    elif shock_type == 'MP':
        # Monetáris politika: Kamat emelkedik (+), Forint erősödik (FX_Change < 0)
        return S_column[3] > 0 and S_column[6] < 0
    elif shock_type == 'DEM':
        # Keresleti sokk: Infláció nő (+), GDP nő (+)
        return S_column[4] > 0 and S_column[5] > 0
    elif shock_type == 'SUPP':
        # Kínálati sokk: Infláció csökken (-), GDP nő (+)
        return S_column[4] < 0 and S_column[5] > 0
    return False

def check_reppa_signs(S_column, shock_type, tol=1e-2):
    # S_column indices: 3:Base_Rate, 4:Inflation, 5:GDP_Growth, 6:FX_Change

    if shock_type == 'PREM':
        # Kamat +, FX gyengül (+), Inf=0, GDP=0
        return (S_column[3] > 0 and S_column[6] > 0 and
                abs(S_column[4]) < tol and abs(S_column[5]) < tol)

    elif shock_type == 'MP':
        # Kamat +, FX erősödik (-), Inf=0, GDP=0
        return (S_column[3] > 0 and S_column[6] < 0 and
                abs(S_column[4]) < tol and abs(S_column[5]) < tol)

    elif shock_type == 'DEM':
        # Keresleti: Inf +, GDP +
        return S_column[4] > 0 and S_column[5] > 0

    elif shock_type == 'SUPP':
        # Kínálati: Inf -, GDP +
        return S_column[4] < 0 and S_column[5] > 0

    return False

# --- 2. STRUKTURÁLIS IRF GENERÁLÁSA ---
def run_structural_simulation(results, target_n, steps):
    state_names = ['Level', 'Slope', 'Curvature', 'Base_Rate', 'Inflation', 'GDP_Growth', 'FX_Change']
    shocks = ['PREM', 'MP', 'DEM', 'SUPP']

    T = results.model.ssm['transition', :, :, 0]
    Q = results.model.ssm['state_cov', :, :, 0]
    P = cholesky(Q, lower=True) # Zérus megkötések biztosítása (Cholesky)

    storage = {s: [] for s in shocks}
    print(f"Szimuláció indítása... Cél: {target_n} sikeres minta / sokk típus")

    attempts = 0
    while any(len(v) < target_n for v in storage.values()):
        attempts += 1
        # Véletlen ortogonális rotáció (Haar-measure)
        X = np.random.randn(7, 7)
        O, _ = qr(X)
        S = P @ O

        for i in range(7):
            candidate_col = S[:, i]
            for s_name in shocks:
                if len(storage[s_name]) < target_n:
                    if check_reppa_signs(candidate_col, s_name):
                        # Pálya kiszámítása
                        path = []
                        curr = candidate_col
                        for _ in range(steps + 1):
                            path.append(curr)
                            curr = T @ curr
                        storage[s_name].append(np.array(path))

        if attempts % 1000 == 0:
            progress = [len(v) for v in storage.values()]
            print(f"Próbálkozások: {attempts} | Gyűjtött minták: {progress}")

    # Statisztikák (Medián és Konfidencia sávok)
    final_output = {}
    for s_name in shocks:
        data = np.array(storage[s_name])
        final_output[s_name] = {
            'median': np.median(data, axis=0),
            'low': np.percentile(data, CONFIDENCE_INTERVAL[0], axis=0),
            'high': np.percentile(data, CONFIDENCE_INTERVAL[1], axis=0)
        }
    return final_output

# --- 3. MEGJELENÍTÉS (7x4 MÁTRIX) ---
irf_results = run_structural_simulation(res, N_SUCCESSFUL_SAMPLES, IRF_STEPS)
shock_list = ['PREM', 'MP', 'DEM', 'SUPP']
var_list = ['Level', 'Slope', 'Curvature', 'Base_Rate', 'Inflation', 'GDP_Growth', 'FX_Change']

fig, axes = plt.subplots(7, 4, figsize=(15, 20))
plt.subplots_adjust(hspace=0.5, wspace=0.3)

for c_idx, s_name in enumerate(shock_list):
    data = irf_results[s_name]
    for r_idx, v_name in enumerate(var_list):
        ax = axes[r_idx, c_idx]
        v_idx = var_list.index(v_name)

        # Konfidencia sáv
        ax.fill_between(range(IRF_STEPS + 1), data['low'][:, v_idx], data['high'][:, v_idx],
                        color='gray', alpha=0.3, label=f'{CONFIDENCE_INTERVAL[0]}-{CONFIDENCE_INTERVAL[1]}%')
        # Strukturális Medián IRF
        ax.plot(data['median'][:, v_idx], color='black', linewidth=1.5)
        ax.axhline(0, color='red', linestyle='--', linewidth=0.8)

        if r_idx == 0: ax.set_title(f"Impulse: {s_name}", fontweight='bold', fontsize=12)
        if c_idx == 0: ax.set_ylabel(v_name, fontweight='bold', fontsize=10)
        ax.grid(True, alpha=0.15)
        ax.tick_params(labelsize=8)

plt.suptitle(f"Structural IRF Matrix ({N_SUCCESSFUL_SAMPLES} successful samples)", fontsize=16, y=0.92)
plt.show()
# Out:
# Szimuláció indítása... Cél: 5000 sikeres minta / sokk típus
# Próbálkozások: 1000 | Gyűjtött minták: [6, 1, 1470, 1728]
# Próbálkozások: 2000 | Gyűjtött minták: [12, 2, 2893, 3524]
# Próbálkozások: 3000 | Gyűjtött minták: [16, 8, 4290, 5000]
# Próbálkozások: 4000 | Gyűjtött minták: [21, 12, 5000, 5000]
# Próbálkozások: 5000 | Gyűjtött minták: [24, 16, 5000, 5000]
# Próbálkozások: 6000 | Gyűjtött minták: [26, 21, 5000, 5000]
# Próbálkozások: 7000 | Gyűjtött minták: [34, 25, 5000, 5000]
# Próbálkozások: 8000 | Gyűjtött minták: [38, 28, 5000, 5000]
# Próbálkozások: 9000 | Gyűjtött minták: [45, 32, 5000, 5000]
# Próbálkozások: 10000 | Gyűjtött minták: [49, 36, 5000, 5000]
# Próbálkozások: 11000 | Gyűjtött minták: [54, 43, 5000, 5000]
# Próbálkozások: 12000 | Gyűjtött minták: [59, 46, 5000, 5000]
# Próbálkozások: 13000 | Gyűjtött minták: [62, 49, 5000, 5000]
# Próbálkozások: 14000 | Gyűjtött minták: [66, 52, 5000, 5000]
# Próbálkozások: 15000 | Gyűjtött minták: [71, 55, 5000, 5000]
# Próbálkozások: 16000 | Gyűjtött minták: [77, 61, 5000, 5000]
# Próbálkozások: 17000 | Gyűjtött minták: [82, 66, 5000, 5000]
# Próbálkozások: 18000 | Gyűjtött minták: [88, 69, 5000, 5000]
# Próbálkozások: 19000 | Gyűjtött minták: [92, 77, 5000, 5000]
# Próbálkozások: 20000 | Gyűjtött minták: [97, 84, 5000, 5000]
# Próbálkozások: 21000 | Gyűjtött minták: [101, 87, 5000, 5000]
# Próbálkozások: 22000 | Gyűjtött minták: [103, 92, 5000, 5000]
# Próbálkozások: 23000 | Gyűjtött minták: [107, 97, 5000, 5000]
# Próbálkozások: 24000 | Gyűjtött minták: [110, 102, 5000, 5000]
# Próbálkozások: 25000 | Gyűjtött minták: [115, 106, 5000, 5000]
# Próbálkozások: 26000 | Gyűjtött minták: [117, 109, 5000, 5000]
# Próbálkozások: 27000 | Gyűjtött minták: [121, 113, 5000, 5000]
# Próbálkozások: 28000 | Gyűjtött minták: [121, 118, 5000, 5000]
# Próbálkozások: 29000 | Gyűjtött minták: [127, 121, 5000, 5000]
# Próbálkozások: 30000 | Gyűjtött minták: [132, 124, 5000, 5000]
# Próbálkozások: 31000 | Gyűjtött minták: [134, 128, 5000, 5000]
# Próbálkozások: 32000 | Gyűjtött minták: [141, 133, 5000, 5000]
# Próbálkozások: 33000 | Gyűjtött minták: [148, 134, 5000, 5000]
# Próbálkozások: 34000 | Gyűjtött minták: [156, 138, 5000, 5000]
# Próbálkozások: 35000 | Gyűjtött minták: [164, 142, 5000, 5000]
# Próbálkozások: 36000 | Gyűjtött minták: [167, 143, 5000, 5000]
# Próbálkozások: 37000 | Gyűjtött minták: [173, 149, 5000, 5000]
# Próbálkozások: 38000 | Gyűjtött minták: [177, 153, 5000, 5000]
# Próbálkozások: 39000 | Gyűjtött minták: [183, 160, 5000, 5000]
# Próbálkozások: 40000 | Gyűjtött minták: [189, 163, 5000, 5000]
# Próbálkozások: 41000 | Gyűjtött minták: [193, 165, 5000, 5000]
# Próbálkozások: 42000 | Gyűjtött minták: [198, 167, 5000, 5000]
# Próbálkozások: 43000 | Gyűjtött minták: [204, 167, 5000, 5000]
# Próbálkozások: 44000 | Gyűjtött minták: [207, 172, 5000, 5000]
# Próbálkozások: 45000 | Gyűjtött minták: [210, 177, 5000, 5000]
# Próbálkozások: 46000 | Gyűjtött minták: [213, 180, 5000, 5000]
# Próbálkozások: 47000 | Gyűjtött minták: [219, 186, 5000, 5000]
# Próbálkozások: 48000 | Gyűjtött minták: [224, 190, 5000, 5000]
# Próbálkozások: 49000 | Gyűjtött minták: [234, 193, 5000, 5000]
# Próbálkozások: 50000 | Gyűjtött minták: [239, 196, 5000, 5000]
# Próbálkozások: 51000 | Gyűjtött minták: [246, 199, 5000, 5000]
# Próbálkozások: 52000 | Gyűjtött minták: [249, 203, 5000, 5000]
# Próbálkozások: 53000 | Gyűjtött minták: [252, 204, 5000, 5000]
# Próbálkozások: 54000 | Gyűjtött minták: [258, 207, 5000, 5000]
# Próbálkozások: 55000 | Gyűjtött minták: [265, 208, 5000, 5000]
# Próbálkozások: 56000 | Gyűjtött minták: [271, 209, 5000, 5000]
# Próbálkozások: 57000 | Gyűjtött minták: [276, 213, 5000, 5000]
# Próbálkozások: 58000 | Gyűjtött minták: [279, 216, 5000, 5000]
# Próbálkozások: 59000 | Gyűjtött minták: [283, 219, 5000, 5000]
# Próbálkozások: 60000 | Gyűjtött minták: [287, 225, 5000, 5000]
# Próbálkozások: 61000 | Gyűjtött minták: [291, 228, 5000, 5000]
# Próbálkozások: 62000 | Gyűjtött minták: [296, 232, 5000, 5000]
# Próbálkozások: 63000 | Gyűjtött minták: [302, 232, 5000, 5000]
# Próbálkozások: 64000 | Gyűjtött minták: [307, 236, 5000, 5000]
# Próbálkozások: 65000 | Gyűjtött minták: [309, 244, 5000, 5000]
# Próbálkozások: 66000 | Gyűjtött minták: [315, 247, 5000, 5000]
# Próbálkozások: 67000 | Gyűjtött minták: [319, 256, 5000, 5000]
# Próbálkozások: 68000 | Gyűjtött minták: [323, 261, 5000, 5000]
# Próbálkozások: 69000 | Gyűjtött minták: [325, 267, 5000, 5000]
# Próbálkozások: 70000 | Gyűjtött minták: [331, 271, 5000, 5000]
# Próbálkozások: 71000 | Gyűjtött minták: [336, 276, 5000, 5000]
# Próbálkozások: 72000 | Gyűjtött minták: [343, 281, 5000, 5000]
# Próbálkozások: 73000 | Gyűjtött minták: [348, 287, 5000, 5000]
# Próbálkozások: 74000 | Gyűjtött minták: [355, 290, 5000, 5000]
# Próbálkozások: 75000 | Gyűjtött minták: [355, 295, 5000, 5000]
# Próbálkozások: 76000 | Gyűjtött minták: [361, 298, 5000, 5000]
# Próbálkozások: 77000 | Gyűjtött minták: [364, 301, 5000, 5000]
# Próbálkozások: 78000 | Gyűjtött minták: [367, 307, 5000, 5000]
# Próbálkozások: 79000 | Gyűjtött minták: [373, 310, 5000, 5000]
# Próbálkozások: 80000 | Gyűjtött minták: [381, 314, 5000, 5000]
# Próbálkozások: 81000 | Gyűjtött minták: [387, 319, 5000, 5000]
# Próbálkozások: 82000 | Gyűjtött minták: [390, 323, 5000, 5000]
# Próbálkozások: 83000 | Gyűjtött minták: [396, 329, 5000, 5000]
# Próbálkozások: 84000 | Gyűjtött minták: [403, 333, 5000, 5000]
# Próbálkozások: 85000 | Gyűjtött minták: [409, 335, 5000, 5000]
# Próbálkozások: 86000 | Gyűjtött minták: [416, 339, 5000, 5000]
# Próbálkozások: 87000 | Gyűjtött minták: [420, 344, 5000, 5000]
# Próbálkozások: 88000 | Gyűjtött minták: [423, 350, 5000, 5000]
# Próbálkozások: 89000 | Gyűjtött minták: [425, 353, 5000, 5000]
# Próbálkozások: 90000 | Gyűjtött minták: [428, 356, 5000, 5000]
# Próbálkozások: 91000 | Gyűjtött minták: [430, 359, 5000, 5000]
# Próbálkozások: 92000 | Gyűjtött minták: [435, 364, 5000, 5000]
# Próbálkozások: 93000 | Gyűjtött minták: [437, 369, 5000, 5000]
# Próbálkozások: 94000 | Gyűjtött minták: [441, 373, 5000, 5000]
# Próbálkozások: 95000 | Gyűjtött minták: [448, 377, 5000, 5000]
# Próbálkozások: 96000 | Gyűjtött minták: [455, 381, 5000, 5000]
# Próbálkozások: 97000 | Gyűjtött minták: [460, 384, 5000, 5000]
# Próbálkozások: 98000 | Gyűjtött minták: [464, 388, 5000, 5000]
# Próbálkozások: 99000 | Gyűjtött minták: [470, 394, 5000, 5000]
# Próbálkozások: 100000 | Gyűjtött minták: [476, 395, 5000, 5000]
# Próbálkozások: 101000 | Gyűjtött minták: [482, 398, 5000, 5000]
# Próbálkozások: 102000 | Gyűjtött minták: [484, 403, 5000, 5000]
# Próbálkozások: 103000 | Gyűjtött minták: [490, 408, 5000, 5000]
# Próbálkozások: 104000 | Gyűjtött minták: [495, 412, 5000, 5000]
# Próbálkozások: 105000 | Gyűjtött minták: [499, 418, 5000, 5000]
# Próbálkozások: 106000 | Gyűjtött minták: [504, 422, 5000, 5000]
# Próbálkozások: 107000 | Gyűjtött minták: [509, 426, 5000, 5000]
# Próbálkozások: 108000 | Gyűjtött minták: [511, 429, 5000, 5000]
# Próbálkozások: 109000 | Gyűjtött minták: [516, 432, 5000, 5000]
# Próbálkozások: 110000 | Gyűjtött minták: [521, 433, 5000, 5000]
# Próbálkozások: 111000 | Gyűjtött minták: [525, 438, 5000, 5000]
# Próbálkozások: 112000 | Gyűjtött minták: [528, 444, 5000, 5000]
# Próbálkozások: 113000 | Gyűjtött minták: [537, 446, 5000, 5000]
# Próbálkozások: 114000 | Gyűjtött minták: [542, 448, 5000, 5000]
# Próbálkozások: 115000 | Gyűjtött minták: [544, 450, 5000, 5000]
# Próbálkozások: 116000 | Gyűjtött minták: [547, 451, 5000, 5000]
# Próbálkozások: 117000 | Gyűjtött minták: [554, 453, 5000, 5000]
# Próbálkozások: 118000 | Gyűjtött minták: [562, 457, 5000, 5000]
# Próbálkozások: 119000 | Gyűjtött minták: [569, 461, 5000, 5000]
# Próbálkozások: 120000 | Gyűjtött minták: [571, 469, 5000, 5000]
# Próbálkozások: 121000 | Gyűjtött minták: [578, 477, 5000, 5000]
# Próbálkozások: 122000 | Gyűjtött minták: [582, 481, 5000, 5000]
# Próbálkozások: 123000 | Gyűjtött minták: [588, 483, 5000, 5000]
# Próbálkozások: 124000 | Gyűjtött minták: [592, 485, 5000, 5000]
# Próbálkozások: 125000 | Gyűjtött minták: [599, 488, 5000, 5000]
# Próbálkozások: 126000 | Gyűjtött minták: [603, 491, 5000, 5000]
# Próbálkozások: 127000 | Gyűjtött minták: [609, 495, 5000, 5000]
# Próbálkozások: 128000 | Gyűjtött minták: [612, 498, 5000, 5000]
# Próbálkozások: 129000 | Gyűjtött minták: [618, 501, 5000, 5000]
# Próbálkozások: 130000 | Gyűjtött minták: [626, 504, 5000, 5000]
# Próbálkozások: 131000 | Gyűjtött minták: [631, 504, 5000, 5000]
# Próbálkozások: 132000 | Gyűjtött minták: [638, 504, 5000, 5000]
# Próbálkozások: 133000 | Gyűjtött minták: [641, 507, 5000, 5000]
# Próbálkozások: 134000 | Gyűjtött minták: [644, 510, 5000, 5000]
# Próbálkozások: 135000 | Gyűjtött minták: [648, 512, 5000, 5000]
# Próbálkozások: 136000 | Gyűjtött minták: [651, 517, 5000, 5000]
# Próbálkozások: 137000 | Gyűjtött minták: [656, 520, 5000, 5000]
# Próbálkozások: 138000 | Gyűjtött minták: [663, 524, 5000, 5000]
# Próbálkozások: 139000 | Gyűjtött minták: [664, 533, 5000, 5000]
# Próbálkozások: 140000 | Gyűjtött minták: [671, 537, 5000, 5000]
# Próbálkozások: 141000 | Gyűjtött minták: [675, 541, 5000, 5000]
# Próbálkozások: 142000 | Gyűjtött minták: [679, 549, 5000, 5000]
# Próbálkozások: 143000 | Gyűjtött minták: [684, 552, 5000, 5000]
# Próbálkozások: 144000 | Gyűjtött minták: [688, 555, 5000, 5000]
# Próbálkozások: 145000 | Gyűjtött minták: [695, 560, 5000, 5000]
# Próbálkozások: 146000 | Gyűjtött minták: [699, 563, 5000, 5000]
# Próbálkozások: 147000 | Gyűjtött minták: [700, 568, 5000, 5000]
# Próbálkozások: 148000 | Gyűjtött minták: [703, 569, 5000, 5000]
# Próbálkozások: 149000 | Gyűjtött minták: [711, 575, 5000, 5000]
# Próbálkozások: 150000 | Gyűjtött minták: [715, 576, 5000, 5000]
# Próbálkozások: 151000 | Gyűjtött minták: [721, 577, 5000, 5000]
# Próbálkozások: 152000 | Gyűjtött minták: [729, 579, 5000, 5000]
# Próbálkozások: 153000 | Gyűjtött minták: [731, 584, 5000, 5000]
# Próbálkozások: 154000 | Gyűjtött minták: [736, 589, 5000, 5000]
# Próbálkozások: 155000 | Gyűjtött minták: [744, 593, 5000, 5000]
# Próbálkozások: 156000 | Gyűjtött minták: [750, 598, 5000, 5000]
# Próbálkozások: 157000 | Gyűjtött minták: [758, 602, 5000, 5000]
# Próbálkozások: 158000 | Gyűjtött minták: [764, 607, 5000, 5000]
# Próbálkozások: 159000 | Gyűjtött minták: [772, 612, 5000, 5000]
# Próbálkozások: 160000 | Gyűjtött minták: [778, 614, 5000, 5000]
# Próbálkozások: 161000 | Gyűjtött minták: [784, 615, 5000, 5000]
# Próbálkozások: 162000 | Gyűjtött minták: [787, 616, 5000, 5000]
# Próbálkozások: 163000 | Gyűjtött minták: [798, 621, 5000, 5000]
# Próbálkozások: 164000 | Gyűjtött minták: [801, 625, 5000, 5000]
# Próbálkozások: 165000 | Gyűjtött minták: [806, 628, 5000, 5000]
# Próbálkozások: 166000 | Gyűjtött minták: [810, 630, 5000, 5000]
# Próbálkozások: 167000 | Gyűjtött minták: [816, 637, 5000, 5000]
# Próbálkozások: 168000 | Gyűjtött minták: [824, 641, 5000, 5000]
# Próbálkozások: 169000 | Gyűjtött minták: [837, 644, 5000, 5000]
# Próbálkozások: 170000 | Gyűjtött minták: [846, 648, 5000, 5000]
# Próbálkozások: 171000 | Gyűjtött minták: [850, 652, 5000, 5000]
# Próbálkozások: 172000 | Gyűjtött minták: [855, 655, 5000, 5000]
# Próbálkozások: 173000 | Gyűjtött minták: [861, 658, 5000, 5000]
# Próbálkozások: 174000 | Gyűjtött minták: [865, 663, 5000, 5000]
# Próbálkozások: 175000 | Gyűjtött minták: [872, 669, 5000, 5000]
# Próbálkozások: 176000 | Gyűjtött minták: [879, 674, 5000, 5000]
# Próbálkozások: 177000 | Gyűjtött minták: [883, 677, 5000, 5000]
# Próbálkozások: 178000 | Gyűjtött minták: [886, 683, 5000, 5000]
# Próbálkozások: 179000 | Gyűjtött minták: [893, 688, 5000, 5000]
# Próbálkozások: 180000 | Gyűjtött minták: [897, 691, 5000, 5000]
# Próbálkozások: 181000 | Gyűjtött minták: [901, 697, 5000, 5000]
# Próbálkozások: 182000 | Gyűjtött minták: [903, 701, 5000, 5000]
# Próbálkozások: 183000 | Gyűjtött minták: [906, 708, 5000, 5000]
# Próbálkozások: 184000 | Gyűjtött minták: [910, 710, 5000, 5000]
# Próbálkozások: 185000 | Gyűjtött minták: [912, 714, 5000, 5000]
# Próbálkozások: 186000 | Gyűjtött minták: [922, 717, 5000, 5000]
# Próbálkozások: 187000 | Gyűjtött minták: [931, 721, 5000, 5000]
# Próbálkozások: 188000 | Gyűjtött minták: [932, 723, 5000, 5000]
# Próbálkozások: 189000 | Gyűjtött minták: [934, 726, 5000, 5000]
# Próbálkozások: 190000 | Gyűjtött minták: [937, 731, 5000, 5000]
# Próbálkozások: 191000 | Gyűjtött minták: [945, 735, 5000, 5000]
# Próbálkozások: 192000 | Gyűjtött minták: [948, 740, 5000, 5000]
# Próbálkozások: 193000 | Gyűjtött minták: [952, 743, 5000, 5000]
# Próbálkozások: 194000 | Gyűjtött minták: [956, 753, 5000, 5000]
# Próbálkozások: 195000 | Gyűjtött minták: [963, 760, 5000, 5000]
# Próbálkozások: 196000 | Gyűjtött minták: [970, 763, 5000, 5000]
# Próbálkozások: 197000 | Gyűjtött minták: [971, 766, 5000, 5000]
# Próbálkozások: 198000 | Gyűjtött minták: [979, 770, 5000, 5000]
# Próbálkozások: 199000 | Gyűjtött minták: [980, 772, 5000, 5000]
# Próbálkozások: 200000 | Gyűjtött minták: [987, 774, 5000, 5000]
# Próbálkozások: 201000 | Gyűjtött minták: [990, 780, 5000, 5000]
# Próbálkozások: 202000 | Gyűjtött minták: [998, 782, 5000, 5000]
# Próbálkozások: 203000 | Gyűjtött minták: [1003, 786, 5000, 5000]
# Próbálkozások: 204000 | Gyűjtött minták: [1009, 790, 5000, 5000]
# Próbálkozások: 205000 | Gyűjtött minták: [1011, 794, 5000, 5000]
# Próbálkozások: 206000 | Gyűjtött minták: [1015, 799, 5000, 5000]
# Próbálkozások: 207000 | Gyűjtött minták: [1020, 802, 5000, 5000]
# Próbálkozások: 208000 | Gyűjtött minták: [1021, 807, 5000, 5000]
# Próbálkozások: 209000 | Gyűjtött minták: [1027, 811, 5000, 5000]
# Próbálkozások: 210000 | Gyűjtött minták: [1031, 817, 5000, 5000]
# Próbálkozások: 211000 | Gyűjtött minták: [1034, 820, 5000, 5000]
# Próbálkozások: 212000 | Gyűjtött minták: [1040, 830, 5000, 5000]
# Próbálkozások: 213000 | Gyűjtött minták: [1045, 833, 5000, 5000]
# Próbálkozások: 214000 | Gyűjtött minták: [1051, 836, 5000, 5000]
# Próbálkozások: 215000 | Gyűjtött minták: [1056, 840, 5000, 5000]
# Próbálkozások: 216000 | Gyűjtött minták: [1062, 843, 5000, 5000]
# Próbálkozások: 217000 | Gyűjtött minták: [1066, 845, 5000, 5000]
# Próbálkozások: 218000 | Gyűjtött minták: [1075, 849, 5000, 5000]
# Próbálkozások: 219000 | Gyűjtött minták: [1075, 855, 5000, 5000]
# Próbálkozások: 220000 | Gyűjtött minták: [1075, 860, 5000, 5000]
# Próbálkozások: 221000 | Gyűjtött minták: [1082, 863, 5000, 5000]
# Próbálkozások: 222000 | Gyűjtött minták: [1088, 868, 5000, 5000]
# Próbálkozások: 223000 | Gyűjtött minták: [1093, 869, 5000, 5000]
# Próbálkozások: 224000 | Gyűjtött minták: [1095, 872, 5000, 5000]
# Próbálkozások: 225000 | Gyűjtött minták: [1099, 879, 5000, 5000]
# Próbálkozások: 226000 | Gyűjtött minták: [1104, 885, 5000, 5000]
# Próbálkozások: 227000 | Gyűjtött minták: [1110, 889, 5000, 5000]
# Próbálkozások: 228000 | Gyűjtött minták: [1115, 892, 5000, 5000]
# Próbálkozások: 229000 | Gyűjtött minták: [1119, 899, 5000, 5000]
# Próbálkozások: 230000 | Gyűjtött minták: [1126, 904, 5000, 5000]
# Próbálkozások: 231000 | Gyűjtött minták: [1133, 905, 5000, 5000]
# Próbálkozások: 232000 | Gyűjtött minták: [1138, 909, 5000, 5000]
# Próbálkozások: 233000 | Gyűjtött minták: [1143, 916, 5000, 5000]
# Próbálkozások: 234000 | Gyűjtött minták: [1149, 918, 5000, 5000]
# Próbálkozások: 235000 | Gyűjtött minták: [1152, 920, 5000, 5000]
# Próbálkozások: 236000 | Gyűjtött minták: [1157, 925, 5000, 5000]
# Próbálkozások: 237000 | Gyűjtött minták: [1160, 927, 5000, 5000]
# Próbálkozások: 238000 | Gyűjtött minták: [1169, 930, 5000, 5000]
# Próbálkozások: 239000 | Gyűjtött minták: [1175, 932, 5000, 5000]
# Próbálkozások: 240000 | Gyűjtött minták: [1176, 933, 5000, 5000]
# Próbálkozások: 241000 | Gyűjtött minták: [1179, 939, 5000, 5000]
# Próbálkozások: 242000 | Gyűjtött minták: [1182, 941, 5000, 5000]
# Próbálkozások: 243000 | Gyűjtött minták: [1190, 945, 5000, 5000]
# Próbálkozások: 244000 | Gyűjtött minták: [1195, 949, 5000, 5000]
# Próbálkozások: 245000 | Gyűjtött minták: [1200, 953, 5000, 5000]
# Próbálkozások: 246000 | Gyűjtött minták: [1205, 957, 5000, 5000]
# Próbálkozások: 247000 | Gyűjtött minták: [1208, 957, 5000, 5000]
# Próbálkozások: 248000 | Gyűjtött minták: [1209, 960, 5000, 5000]
# Próbálkozások: 249000 | Gyűjtött minták: [1211, 964, 5000, 5000]
# Próbálkozások: 250000 | Gyűjtött minták: [1215, 966, 5000, 5000]
# Próbálkozások: 251000 | Gyűjtött minták: [1218, 969, 5000, 5000]
# Próbálkozások: 252000 | Gyűjtött minták: [1222, 971, 5000, 5000]
# Próbálkozások: 253000 | Gyűjtött minták: [1225, 974, 5000, 5000]
# Próbálkozások: 254000 | Gyűjtött minták: [1233, 976, 5000, 5000]
# Próbálkozások: 255000 | Gyűjtött minták: [1240, 979, 5000, 5000]
# Próbálkozások: 256000 | Gyűjtött minták: [1243, 982, 5000, 5000]
# Próbálkozások: 257000 | Gyűjtött minták: [1249, 985, 5000, 5000]
# Próbálkozások: 258000 | Gyűjtött minták: [1253, 985, 5000, 5000]
# Próbálkozások: 259000 | Gyűjtött minták: [1261, 987, 5000, 5000]
# Próbálkozások: 260000 | Gyűjtött minták: [1263, 993, 5000, 5000]
# Próbálkozások: 261000 | Gyűjtött minták: [1271, 997, 5000, 5000]
# Próbálkozások: 262000 | Gyűjtött minták: [1274, 1002, 5000, 5000]
# Próbálkozások: 263000 | Gyűjtött minták: [1276, 1004, 5000, 5000]
# Próbálkozások: 264000 | Gyűjtött minták: [1284, 1007, 5000, 5000]
# Próbálkozások: 265000 | Gyűjtött minták: [1287, 1011, 5000, 5000]
# Próbálkozások: 266000 | Gyűjtött minták: [1295, 1018, 5000, 5000]
# Próbálkozások: 267000 | Gyűjtött minták: [1298, 1021, 5000, 5000]
# Próbálkozások: 268000 | Gyűjtött minták: [1301, 1023, 5000, 5000]
# Próbálkozások: 269000 | Gyűjtött minták: [1305, 1030, 5000, 5000]
# Próbálkozások: 270000 | Gyűjtött minták: [1307, 1034, 5000, 5000]
# Próbálkozások: 271000 | Gyűjtött minták: [1316, 1038, 5000, 5000]
# Próbálkozások: 272000 | Gyűjtött minták: [1318, 1041, 5000, 5000]
# Próbálkozások: 273000 | Gyűjtött minták: [1323, 1044, 5000, 5000]
# Próbálkozások: 274000 | Gyűjtött minták: [1326, 1049, 5000, 5000]
# Próbálkozások: 275000 | Gyűjtött minták: [1331, 1052, 5000, 5000]
# Próbálkozások: 276000 | Gyűjtött minták: [1335, 1053, 5000, 5000]
# Próbálkozások: 277000 | Gyűjtött minták: [1341, 1056, 5000, 5000]
# Próbálkozások: 278000 | Gyűjtött minták: [1347, 1061, 5000, 5000]
# Próbálkozások: 279000 | Gyűjtött minták: [1351, 1065, 5000, 5000]
# Próbálkozások: 280000 | Gyűjtött minták: [1363, 1066, 5000, 5000]
# Próbálkozások: 281000 | Gyűjtött minták: [1363, 1070, 5000, 5000]
# Próbálkozások: 282000 | Gyűjtött minták: [1371, 1080, 5000, 5000]
# Próbálkozások: 283000 | Gyűjtött minták: [1372, 1086, 5000, 5000]
# Próbálkozások: 284000 | Gyűjtött minták: [1373, 1088, 5000, 5000]
# Próbálkozások: 285000 | Gyűjtött minták: [1377, 1096, 5000, 5000]
# Próbálkozások: 286000 | Gyűjtött minták: [1382, 1097, 5000, 5000]
# Próbálkozások: 287000 | Gyűjtött minták: [1384, 1100, 5000, 5000]
# Próbálkozások: 288000 | Gyűjtött minták: [1388, 1104, 5000, 5000]
# Próbálkozások: 289000 | Gyűjtött minták: [1391, 1105, 5000, 5000]
# Próbálkozások: 290000 | Gyűjtött minták: [1395, 1106, 5000, 5000]
# Próbálkozások: 291000 | Gyűjtött minták: [1398, 1109, 5000, 5000]
# Próbálkozások: 292000 | Gyűjtött minták: [1405, 1116, 5000, 5000]
# Próbálkozások: 293000 | Gyűjtött minták: [1413, 1120, 5000, 5000]
# Próbálkozások: 294000 | Gyűjtött minták: [1418, 1123, 5000, 5000]
# Próbálkozások: 295000 | Gyűjtött minták: [1424, 1124, 5000, 5000]
# Próbálkozások: 296000 | Gyűjtött minták: [1432, 1131, 5000, 5000]
# Próbálkozások: 297000 | Gyűjtött minták: [1436, 1133, 5000, 5000]
# Próbálkozások: 298000 | Gyűjtött minták: [1439, 1135, 5000, 5000]
# Próbálkozások: 299000 | Gyűjtött minták: [1443, 1136, 5000, 5000]
# Próbálkozások: 300000 | Gyűjtött minták: [1448, 1137, 5000, 5000]
# Próbálkozások: 301000 | Gyűjtött minták: [1452, 1139, 5000, 5000]
# Próbálkozások: 302000 | Gyűjtött minták: [1458, 1144, 5000, 5000]
# Próbálkozások: 303000 | Gyűjtött minták: [1462, 1148, 5000, 5000]
# Próbálkozások: 304000 | Gyűjtött minták: [1466, 1150, 5000, 5000]
# Próbálkozások: 305000 | Gyűjtött minták: [1468, 1153, 5000, 5000]
# Próbálkozások: 306000 | Gyűjtött minták: [1473, 1156, 5000, 5000]
# Próbálkozások: 307000 | Gyűjtött minták: [1482, 1164, 5000, 5000]
# Próbálkozások: 308000 | Gyűjtött minták: [1484, 1170, 5000, 5000]
# Próbálkozások: 309000 | Gyűjtött minták: [1494, 1174, 5000, 5000]
# Próbálkozások: 310000 | Gyűjtött minták: [1503, 1179, 5000, 5000]
# Próbálkozások: 311000 | Gyűjtött minták: [1509, 1183, 5000, 5000]
# Próbálkozások: 312000 | Gyűjtött minták: [1514, 1184, 5000, 5000]
# Próbálkozások: 313000 | Gyűjtött minták: [1522, 1186, 5000, 5000]
# Próbálkozások: 314000 | Gyűjtött minták: [1527, 1190, 5000, 5000]
# Próbálkozások: 315000 | Gyűjtött minták: [1534, 1196, 5000, 5000]
# Próbálkozások: 316000 | Gyűjtött minták: [1535, 1199, 5000, 5000]
# Próbálkozások: 317000 | Gyűjtött minták: [1543, 1202, 5000, 5000]
# Próbálkozások: 318000 | Gyűjtött minták: [1550, 1207, 5000, 5000]
# Próbálkozások: 319000 | Gyűjtött minták: [1556, 1213, 5000, 5000]
# Próbálkozások: 320000 | Gyűjtött minták: [1561, 1214, 5000, 5000]
# Próbálkozások: 321000 | Gyűjtött minták: [1568, 1215, 5000, 5000]
# Próbálkozások: 322000 | Gyűjtött minták: [1570, 1219, 5000, 5000]
# Próbálkozások: 323000 | Gyűjtött minták: [1576, 1221, 5000, 5000]
# Próbálkozások: 324000 | Gyűjtött minták: [1581, 1223, 5000, 5000]
# Próbálkozások: 325000 | Gyűjtött minták: [1586, 1227, 5000, 5000]
# Próbálkozások: 326000 | Gyűjtött minták: [1589, 1229, 5000, 5000]
# Próbálkozások: 327000 | Gyűjtött minták: [1594, 1233, 5000, 5000]
# Próbálkozások: 328000 | Gyűjtött minták: [1598, 1238, 5000, 5000]
# Próbálkozások: 329000 | Gyűjtött minták: [1603, 1241, 5000, 5000]
# Próbálkozások: 330000 | Gyűjtött minták: [1606, 1248, 5000, 5000]
# Próbálkozások: 331000 | Gyűjtött minták: [1609, 1249, 5000, 5000]
# Próbálkozások: 332000 | Gyűjtött minták: [1614, 1253, 5000, 5000]
# Próbálkozások: 333000 | Gyűjtött minták: [1622, 1254, 5000, 5000]
# Próbálkozások: 334000 | Gyűjtött minták: [1627, 1257, 5000, 5000]
# Próbálkozások: 335000 | Gyűjtött minták: [1631, 1260, 5000, 5000]
# Próbálkozások: 336000 | Gyűjtött minták: [1634, 1263, 5000, 5000]
# Próbálkozások: 337000 | Gyűjtött minták: [1637, 1269, 5000, 5000]
# Próbálkozások: 338000 | Gyűjtött minták: [1640, 1271, 5000, 5000]
# Próbálkozások: 339000 | Gyűjtött minták: [1648, 1274, 5000, 5000]
# Próbálkozások: 340000 | Gyűjtött minták: [1654, 1280, 5000, 5000]
# Próbálkozások: 341000 | Gyűjtött minták: [1659, 1284, 5000, 5000]
# Próbálkozások: 342000 | Gyűjtött minták: [1662, 1287, 5000, 5000]
# Próbálkozások: 343000 | Gyűjtött minták: [1664, 1293, 5000, 5000]
# Próbálkozások: 344000 | Gyűjtött minták: [1667, 1296, 5000, 5000]
# Próbálkozások: 345000 | Gyűjtött minták: [1672, 1297, 5000, 5000]
# Próbálkozások: 346000 | Gyűjtött minták: [1678, 1299, 5000, 5000]
# Próbálkozások: 347000 | Gyűjtött minták: [1680, 1303, 5000, 5000]
# Próbálkozások: 348000 | Gyűjtött minták: [1683, 1306, 5000, 5000]
# Próbálkozások: 349000 | Gyűjtött minták: [1687, 1306, 5000, 5000]
# Próbálkozások: 350000 | Gyűjtött minták: [1691, 1309, 5000, 5000]
# Próbálkozások: 351000 | Gyűjtött minták: [1693, 1317, 5000, 5000]
# Próbálkozások: 352000 | Gyűjtött minták: [1696, 1320, 5000, 5000]
# Próbálkozások: 353000 | Gyűjtött minták: [1701, 1323, 5000, 5000]
# Próbálkozások: 354000 | Gyűjtött minták: [1705, 1324, 5000, 5000]
# Próbálkozások: 355000 | Gyűjtött minták: [1711, 1327, 5000, 5000]
# Próbálkozások: 356000 | Gyűjtött minták: [1716, 1334, 5000, 5000]
# Próbálkozások: 357000 | Gyűjtött minták: [1722, 1340, 5000, 5000]
# Próbálkozások: 358000 | Gyűjtött minták: [1726, 1343, 5000, 5000]
# Próbálkozások: 359000 | Gyűjtött minták: [1730, 1349, 5000, 5000]
# Próbálkozások: 360000 | Gyűjtött minták: [1738, 1355, 5000, 5000]
# Próbálkozások: 361000 | Gyűjtött minták: [1747, 1360, 5000, 5000]
# Próbálkozások: 362000 | Gyűjtött minták: [1757, 1363, 5000, 5000]
# Próbálkozások: 363000 | Gyűjtött minták: [1767, 1365, 5000, 5000]
# Próbálkozások: 364000 | Gyűjtött minták: [1775, 1371, 5000, 5000]
# Próbálkozások: 365000 | Gyűjtött minták: [1777, 1373, 5000, 5000]
# Próbálkozások: 366000 | Gyűjtött minták: [1784, 1379, 5000, 5000]
# Próbálkozások: 367000 | Gyűjtött minták: [1789, 1386, 5000, 5000]
# Próbálkozások: 368000 | Gyűjtött minták: [1798, 1388, 5000, 5000]
# Próbálkozások: 369000 | Gyűjtött minták: [1802, 1389, 5000, 5000]
# Próbálkozások: 370000 | Gyűjtött minták: [1809, 1389, 5000, 5000]
# Próbálkozások: 371000 | Gyűjtött minták: [1815, 1390, 5000, 5000]
# Próbálkozások: 372000 | Gyűjtött minták: [1823, 1393, 5000, 5000]
# Próbálkozások: 373000 | Gyűjtött minták: [1827, 1395, 5000, 5000]
# Próbálkozások: 374000 | Gyűjtött minták: [1835, 1401, 5000, 5000]
# Próbálkozások: 375000 | Gyűjtött minták: [1839, 1404, 5000, 5000]
# Próbálkozások: 376000 | Gyűjtött minták: [1841, 1407, 5000, 5000]
# Próbálkozások: 377000 | Gyűjtött minták: [1847, 1410, 5000, 5000]
# Próbálkozások: 378000 | Gyűjtött minták: [1850, 1415, 5000, 5000]
# Próbálkozások: 379000 | Gyűjtött minták: [1855, 1419, 5000, 5000]
# Próbálkozások: 380000 | Gyűjtött minták: [1864, 1425, 5000, 5000]
# Próbálkozások: 381000 | Gyűjtött minták: [1869, 1426, 5000, 5000]
# Próbálkozások: 382000 | Gyűjtött minták: [1874, 1428, 5000, 5000]
# Próbálkozások: 383000 | Gyűjtött minták: [1880, 1430, 5000, 5000]
# Próbálkozások: 384000 | Gyűjtött minták: [1884, 1432, 5000, 5000]
# Próbálkozások: 385000 | Gyűjtött minták: [1890, 1436, 5000, 5000]
# Próbálkozások: 386000 | Gyűjtött minták: [1897, 1439, 5000, 5000]
# Próbálkozások: 387000 | Gyűjtött minták: [1902, 1443, 5000, 5000]
# Próbálkozások: 388000 | Gyűjtött minták: [1906, 1444, 5000, 5000]
# Próbálkozások: 389000 | Gyűjtött minták: [1907, 1452, 5000, 5000]
# Próbálkozások: 390000 | Gyűjtött minták: [1910, 1453, 5000, 5000]
# Próbálkozások: 391000 | Gyűjtött minták: [1913, 1457, 5000, 5000]
# Próbálkozások: 392000 | Gyűjtött minták: [1918, 1465, 5000, 5000]
# Próbálkozások: 393000 | Gyűjtött minták: [1924, 1470, 5000, 5000]
# Próbálkozások: 394000 | Gyűjtött minták: [1927, 1475, 5000, 5000]
# Próbálkozások: 395000 | Gyűjtött minták: [1932, 1478, 5000, 5000]
# Próbálkozások: 396000 | Gyűjtött minták: [1937, 1481, 5000, 5000]
# Próbálkozások: 397000 | Gyűjtött minták: [1941, 1485, 5000, 5000]
# Próbálkozások: 398000 | Gyűjtött minták: [1944, 1487, 5000, 5000]
# Próbálkozások: 399000 | Gyűjtött minták: [1946, 1490, 5000, 5000]
# Próbálkozások: 400000 | Gyűjtött minták: [1952, 1493, 5000, 5000]
# Próbálkozások: 401000 | Gyűjtött minták: [1958, 1495, 5000, 5000]
# Próbálkozások: 402000 | Gyűjtött minták: [1962, 1498, 5000, 5000]
# Próbálkozások: 403000 | Gyűjtött minták: [1967, 1500, 5000, 5000]
# Próbálkozások: 404000 | Gyűjtött minták: [1972, 1506, 5000, 5000]
# Próbálkozások: 405000 | Gyűjtött minták: [1977, 1508, 5000, 5000]
# Próbálkozások: 406000 | Gyűjtött minták: [1979, 1515, 5000, 5000]
# Próbálkozások: 407000 | Gyűjtött minták: [1985, 1518, 5000, 5000]
# Próbálkozások: 408000 | Gyűjtött minták: [1986, 1523, 5000, 5000]
# Próbálkozások: 409000 | Gyűjtött minták: [1992, 1525, 5000, 5000]
# Próbálkozások: 410000 | Gyűjtött minták: [1995, 1532, 5000, 5000]
# Próbálkozások: 411000 | Gyűjtött minták: [1998, 1535, 5000, 5000]
# Próbálkozások: 412000 | Gyűjtött minták: [2004, 1542, 5000, 5000]
# Próbálkozások: 413000 | Gyűjtött minták: [2008, 1547, 5000, 5000]
# Próbálkozások: 414000 | Gyűjtött minták: [2012, 1550, 5000, 5000]
# Próbálkozások: 415000 | Gyűjtött minták: [2017, 1552, 5000, 5000]
# Próbálkozások: 416000 | Gyűjtött minták: [2022, 1553, 5000, 5000]
# Próbálkozások: 417000 | Gyűjtött minták: [2027, 1556, 5000, 5000]
# Próbálkozások: 418000 | Gyűjtött minták: [2035, 1560, 5000, 5000]
# Próbálkozások: 419000 | Gyűjtött minták: [2040, 1562, 5000, 5000]
# Próbálkozások: 420000 | Gyűjtött minták: [2044, 1564, 5000, 5000]
# Próbálkozások: 421000 | Gyűjtött minták: [2051, 1565, 5000, 5000]
# Próbálkozások: 422000 | Gyűjtött minták: [2053, 1568, 5000, 5000]
# Próbálkozások: 423000 | Gyűjtött minták: [2057, 1570, 5000, 5000]
# Próbálkozások: 424000 | Gyűjtött minták: [2062, 1573, 5000, 5000]
# Próbálkozások: 425000 | Gyűjtött minták: [2066, 1575, 5000, 5000]
# Próbálkozások: 426000 | Gyűjtött minták: [2071, 1579, 5000, 5000]
# Próbálkozások: 427000 | Gyűjtött minták: [2077, 1583, 5000, 5000]
# Próbálkozások: 428000 | Gyűjtött minták: [2081, 1590, 5000, 5000]
# Próbálkozások: 429000 | Gyűjtött minták: [2082, 1594, 5000, 5000]
# Próbálkozások: 430000 | Gyűjtött minták: [2086, 1596, 5000, 5000]
# Próbálkozások: 431000 | Gyűjtött minták: [2088, 1602, 5000, 5000]
# Próbálkozások: 432000 | Gyűjtött minták: [2090, 1606, 5000, 5000]
# Próbálkozások: 433000 | Gyűjtött minták: [2098, 1609, 5000, 5000]
# Próbálkozások: 434000 | Gyűjtött minták: [2106, 1613, 5000, 5000]
# Próbálkozások: 435000 | Gyűjtött minták: [2112, 1617, 5000, 5000]
# Próbálkozások: 436000 | Gyűjtött minták: [2117, 1621, 5000, 5000]
# Próbálkozások: 437000 | Gyűjtött minták: [2121, 1624, 5000, 5000]
# Próbálkozások: 438000 | Gyűjtött minták: [2129, 1627, 5000, 5000]
# Próbálkozások: 439000 | Gyűjtött minták: [2136, 1629, 5000, 5000]
# Próbálkozások: 440000 | Gyűjtött minták: [2139, 1632, 5000, 5000]
# Próbálkozások: 441000 | Gyűjtött minták: [2142, 1636, 5000, 5000]
# Próbálkozások: 442000 | Gyűjtött minták: [2146, 1640, 5000, 5000]
# Próbálkozások: 443000 | Gyűjtött minták: [2152, 1643, 5000, 5000]
# Próbálkozások: 444000 | Gyűjtött minták: [2157, 1645, 5000, 5000]
# Próbálkozások: 445000 | Gyűjtött minták: [2167, 1648, 5000, 5000]
# Próbálkozások: 446000 | Gyűjtött minták: [2174, 1650, 5000, 5000]
# Próbálkozások: 447000 | Gyűjtött minták: [2177, 1654, 5000, 5000]
# Próbálkozások: 448000 | Gyűjtött minták: [2180, 1659, 5000, 5000]
# Próbálkozások: 449000 | Gyűjtött minták: [2185, 1663, 5000, 5000]
# Próbálkozások: 450000 | Gyűjtött minták: [2193, 1669, 5000, 5000]
# Próbálkozások: 451000 | Gyűjtött minták: [2194, 1674, 5000, 5000]
# Próbálkozások: 452000 | Gyűjtött minták: [2197, 1678, 5000, 5000]
# Próbálkozások: 453000 | Gyűjtött minták: [2203, 1680, 5000, 5000]
# Próbálkozások: 454000 | Gyűjtött minták: [2207, 1684, 5000, 5000]
# Próbálkozások: 455000 | Gyűjtött minták: [2213, 1688, 5000, 5000]
# Próbálkozások: 456000 | Gyűjtött minták: [2218, 1692, 5000, 5000]
# Próbálkozások: 457000 | Gyűjtött minták: [2220, 1695, 5000, 5000]
# Próbálkozások: 458000 | Gyűjtött minták: [2223, 1698, 5000, 5000]
# Próbálkozások: 459000 | Gyűjtött minták: [2231, 1700, 5000, 5000]
# Próbálkozások: 460000 | Gyűjtött minták: [2234, 1701, 5000, 5000]
# Próbálkozások: 461000 | Gyűjtött minták: [2236, 1705, 5000, 5000]
# Próbálkozások: 462000 | Gyűjtött minták: [2240, 1708, 5000, 5000]
# Próbálkozások: 463000 | Gyűjtött minták: [2243, 1711, 5000, 5000]
# Próbálkozások: 464000 | Gyűjtött minták: [2249, 1717, 5000, 5000]
# Próbálkozások: 465000 | Gyűjtött minták: [2256, 1723, 5000, 5000]
# Próbálkozások: 466000 | Gyűjtött minták: [2258, 1727, 5000, 5000]
# Próbálkozások: 467000 | Gyűjtött minták: [2264, 1729, 5000, 5000]
# Próbálkozások: 468000 | Gyűjtött minták: [2266, 1732, 5000, 5000]
# Próbálkozások: 469000 | Gyűjtött minták: [2271, 1736, 5000, 5000]
# Próbálkozások: 470000 | Gyűjtött minták: [2276, 1739, 5000, 5000]
# Próbálkozások: 471000 | Gyűjtött minták: [2283, 1747, 5000, 5000]
# Próbálkozások: 472000 | Gyűjtött minták: [2288, 1748, 5000, 5000]
# Próbálkozások: 473000 | Gyűjtött minták: [2293, 1754, 5000, 5000]
# Próbálkozások: 474000 | Gyűjtött minták: [2295, 1756, 5000, 5000]
# Próbálkozások: 475000 | Gyűjtött minták: [2301, 1762, 5000, 5000]
# Próbálkozások: 476000 | Gyűjtött minták: [2307, 1765, 5000, 5000]
# Próbálkozások: 477000 | Gyűjtött minták: [2308, 1768, 5000, 5000]
# Próbálkozások: 478000 | Gyűjtött minták: [2310, 1772, 5000, 5000]
# Próbálkozások: 479000 | Gyűjtött minták: [2315, 1776, 5000, 5000]
# Próbálkozások: 480000 | Gyűjtött minták: [2318, 1777, 5000, 5000]
# Próbálkozások: 481000 | Gyűjtött minták: [2320, 1782, 5000, 5000]
# Próbálkozások: 482000 | Gyűjtött minták: [2326, 1789, 5000, 5000]
# Próbálkozások: 483000 | Gyűjtött minták: [2328, 1796, 5000, 5000]
# Próbálkozások: 484000 | Gyűjtött minták: [2331, 1801, 5000, 5000]
# Próbálkozások: 485000 | Gyűjtött minták: [2334, 1806, 5000, 5000]
# Próbálkozások: 486000 | Gyűjtött minták: [2338, 1811, 5000, 5000]
# Próbálkozások: 487000 | Gyűjtött minták: [2342, 1815, 5000, 5000]
# Próbálkozások: 488000 | Gyűjtött minták: [2347, 1820, 5000, 5000]
# Próbálkozások: 489000 | Gyűjtött minták: [2350, 1821, 5000, 5000]
# Próbálkozások: 490000 | Gyűjtött minták: [2354, 1825, 5000, 5000]
# Próbálkozások: 491000 | Gyűjtött minták: [2358, 1827, 5000, 5000]
# Próbálkozások: 492000 | Gyűjtött minták: [2362, 1829, 5000, 5000]
# Próbálkozások: 493000 | Gyűjtött minták: [2369, 1831, 5000, 5000]
# Próbálkozások: 494000 | Gyűjtött minták: [2370, 1835, 5000, 5000]
# Próbálkozások: 495000 | Gyűjtött minták: [2376, 1840, 5000, 5000]
# Próbálkozások: 496000 | Gyűjtött minták: [2382, 1843, 5000, 5000]
# Próbálkozások: 497000 | Gyűjtött minták: [2387, 1847, 5000, 5000]
# Próbálkozások: 498000 | Gyűjtött minták: [2389, 1851, 5000, 5000]
# Próbálkozások: 499000 | Gyűjtött minták: [2394, 1854, 5000, 5000]
# Próbálkozások: 500000 | Gyűjtött minták: [2398, 1861, 5000, 5000]
# Próbálkozások: 501000 | Gyűjtött minták: [2401, 1863, 5000, 5000]
# Próbálkozások: 502000 | Gyűjtött minták: [2404, 1866, 5000, 5000]
# Próbálkozások: 503000 | Gyűjtött minták: [2408, 1874, 5000, 5000]
# Próbálkozások: 504000 | Gyűjtött minták: [2412, 1877, 5000, 5000]
# Próbálkozások: 505000 | Gyűjtött minták: [2418, 1878, 5000, 5000]
# Próbálkozások: 506000 | Gyűjtött minták: [2425, 1886, 5000, 5000]
# Próbálkozások: 507000 | Gyűjtött minták: [2432, 1887, 5000, 5000]
# Próbálkozások: 508000 | Gyűjtött minták: [2438, 1889, 5000, 5000]
# Próbálkozások: 509000 | Gyűjtött minták: [2447, 1893, 5000, 5000]
# Próbálkozások: 510000 | Gyűjtött minták: [2455, 1895, 5000, 5000]
# Próbálkozások: 511000 | Gyűjtött minták: [2459, 1898, 5000, 5000]
# Próbálkozások: 512000 | Gyűjtött minták: [2461, 1903, 5000, 5000]
# Próbálkozások: 513000 | Gyűjtött minták: [2465, 1905, 5000, 5000]
# Próbálkozások: 514000 | Gyűjtött minták: [2469, 1908, 5000, 5000]
# Próbálkozások: 515000 | Gyűjtött minták: [2474, 1910, 5000, 5000]
# Próbálkozások: 516000 | Gyűjtött minták: [2483, 1913, 5000, 5000]
# Próbálkozások: 517000 | Gyűjtött minták: [2487, 1919, 5000, 5000]
# Próbálkozások: 518000 | Gyűjtött minták: [2492, 1926, 5000, 5000]
# Próbálkozások: 519000 | Gyűjtött minták: [2497, 1928, 5000, 5000]
# Próbálkozások: 520000 | Gyűjtött minták: [2501, 1933, 5000, 5000]
# Próbálkozások: 521000 | Gyűjtött minták: [2508, 1938, 5000, 5000]
# Próbálkozások: 522000 | Gyűjtött minták: [2519, 1942, 5000, 5000]
# Próbálkozások: 523000 | Gyűjtött minták: [2523, 1947, 5000, 5000]
# Próbálkozások: 524000 | Gyűjtött minták: [2530, 1952, 5000, 5000]
# Próbálkozások: 525000 | Gyűjtött minták: [2532, 1958, 5000, 5000]
# Próbálkozások: 526000 | Gyűjtött minták: [2542, 1960, 5000, 5000]
# Próbálkozások: 527000 | Gyűjtött minták: [2550, 1964, 5000, 5000]
# Próbálkozások: 528000 | Gyűjtött minták: [2554, 1968, 5000, 5000]
# Próbálkozások: 529000 | Gyűjtött minták: [2555, 1971, 5000, 5000]
# Próbálkozások: 530000 | Gyűjtött minták: [2558, 1974, 5000, 5000]
# Próbálkozások: 531000 | Gyűjtött minták: [2564, 1980, 5000, 5000]
# Próbálkozások: 532000 | Gyűjtött minták: [2568, 1985, 5000, 5000]
# Próbálkozások: 533000 | Gyűjtött minták: [2573, 1991, 5000, 5000]
# Próbálkozások: 534000 | Gyűjtött minták: [2577, 1996, 5000, 5000]
# Próbálkozások: 535000 | Gyűjtött minták: [2584, 2003, 5000, 5000]
# Próbálkozások: 536000 | Gyűjtött minták: [2590, 2004, 5000, 5000]
# Próbálkozások: 537000 | Gyűjtött minták: [2595, 2008, 5000, 5000]
# Próbálkozások: 538000 | Gyűjtött minták: [2600, 2009, 5000, 5000]
# Próbálkozások: 539000 | Gyűjtött minták: [2605, 2016, 5000, 5000]
# Próbálkozások: 540000 | Gyűjtött minták: [2609, 2020, 5000, 5000]
# Próbálkozások: 541000 | Gyűjtött minták: [2615, 2027, 5000, 5000]
# Próbálkozások: 542000 | Gyűjtött minták: [2619, 2032, 5000, 5000]
# Próbálkozások: 543000 | Gyűjtött minták: [2626, 2035, 5000, 5000]
# Próbálkozások: 544000 | Gyűjtött minták: [2633, 2041, 5000, 5000]
# Próbálkozások: 545000 | Gyűjtött minták: [2639, 2045, 5000, 5000]
# Próbálkozások: 546000 | Gyűjtött minták: [2642, 2050, 5000, 5000]
# Próbálkozások: 547000 | Gyűjtött minták: [2648, 2056, 5000, 5000]
# Próbálkozások: 548000 | Gyűjtött minták: [2652, 2061, 5000, 5000]
# Próbálkozások: 549000 | Gyűjtött minták: [2656, 2063, 5000, 5000]
# Próbálkozások: 550000 | Gyűjtött minták: [2661, 2068, 5000, 5000]
# Próbálkozások: 551000 | Gyűjtött minták: [2665, 2070, 5000, 5000]
# Próbálkozások: 552000 | Gyűjtött minták: [2667, 2073, 5000, 5000]
# Próbálkozások: 553000 | Gyűjtött minták: [2673, 2077, 5000, 5000]
# Próbálkozások: 554000 | Gyűjtött minták: [2677, 2079, 5000, 5000]
# Próbálkozások: 555000 | Gyűjtött minták: [2684, 2080, 5000, 5000]
# Próbálkozások: 556000 | Gyűjtött minták: [2691, 2086, 5000, 5000]
# Próbálkozások: 557000 | Gyűjtött minták: [2697, 2089, 5000, 5000]
# Próbálkozások: 558000 | Gyűjtött minták: [2700, 2097, 5000, 5000]
# Próbálkozások: 559000 | Gyűjtött minták: [2703, 2101, 5000, 5000]
# Próbálkozások: 560000 | Gyűjtött minták: [2707, 2106, 5000, 5000]
# Próbálkozások: 561000 | Gyűjtött minták: [2714, 2106, 5000, 5000]
# Próbálkozások: 562000 | Gyűjtött minták: [2717, 2115, 5000, 5000]
# Próbálkozások: 563000 | Gyűjtött minták: [2724, 2116, 5000, 5000]
# Próbálkozások: 564000 | Gyűjtött minták: [2729, 2119, 5000, 5000]
# Próbálkozások: 565000 | Gyűjtött minták: [2738, 2122, 5000, 5000]
# Próbálkozások: 566000 | Gyűjtött minták: [2743, 2125, 5000, 5000]
# Próbálkozások: 567000 | Gyűjtött minták: [2746, 2127, 5000, 5000]
# Próbálkozások: 568000 | Gyűjtött minták: [2750, 2133, 5000, 5000]
# Próbálkozások: 569000 | Gyűjtött minták: [2755, 2136, 5000, 5000]
# Próbálkozások: 570000 | Gyűjtött minták: [2759, 2138, 5000, 5000]
# Próbálkozások: 571000 | Gyűjtött minták: [2762, 2143, 5000, 5000]
# Próbálkozások: 572000 | Gyűjtött minták: [2764, 2147, 5000, 5000]
# Próbálkozások: 573000 | Gyűjtött minták: [2766, 2149, 5000, 5000]
# Próbálkozások: 574000 | Gyűjtött minták: [2775, 2152, 5000, 5000]
# Próbálkozások: 575000 | Gyűjtött minták: [2784, 2156, 5000, 5000]
# Próbálkozások: 576000 | Gyűjtött minták: [2789, 2160, 5000, 5000]
# Próbálkozások: 577000 | Gyűjtött minták: [2798, 2168, 5000, 5000]
# Próbálkozások: 578000 | Gyűjtött minták: [2803, 2170, 5000, 5000]
# Próbálkozások: 579000 | Gyűjtött minták: [2808, 2175, 5000, 5000]
# Próbálkozások: 580000 | Gyűjtött minták: [2816, 2176, 5000, 5000]
# Próbálkozások: 581000 | Gyűjtött minták: [2818, 2178, 5000, 5000]
# Próbálkozások: 582000 | Gyűjtött minták: [2821, 2180, 5000, 5000]
# Próbálkozások: 583000 | Gyűjtött minták: [2824, 2185, 5000, 5000]
# Próbálkozások: 584000 | Gyűjtött minták: [2830, 2190, 5000, 5000]
# Próbálkozások: 585000 | Gyűjtött minták: [2838, 2194, 5000, 5000]
# Próbálkozások: 586000 | Gyűjtött minták: [2841, 2201, 5000, 5000]
# Próbálkozások: 587000 | Gyűjtött minták: [2849, 2203, 5000, 5000]
# Próbálkozások: 588000 | Gyűjtött minták: [2853, 2206, 5000, 5000]
# Próbálkozások: 589000 | Gyűjtött minták: [2856, 2211, 5000, 5000]
# Próbálkozások: 590000 | Gyűjtött minták: [2863, 2214, 5000, 5000]
# Próbálkozások: 591000 | Gyűjtött minták: [2865, 2218, 5000, 5000]
# Próbálkozások: 592000 | Gyűjtött minták: [2872, 2221, 5000, 5000]
# Próbálkozások: 593000 | Gyűjtött minták: [2878, 2227, 5000, 5000]
# Próbálkozások: 594000 | Gyűjtött minták: [2886, 2234, 5000, 5000]
# Próbálkozások: 595000 | Gyűjtött minták: [2887, 2237, 5000, 5000]
# Próbálkozások: 596000 | Gyűjtött minták: [2894, 2241, 5000, 5000]
# Próbálkozások: 597000 | Gyűjtött minták: [2902, 2243, 5000, 5000]
# Próbálkozások: 598000 | Gyűjtött minták: [2908, 2249, 5000, 5000]
# Próbálkozások: 599000 | Gyűjtött minták: [2912, 2256, 5000, 5000]
# Próbálkozások: 600000 | Gyűjtött minták: [2915, 2260, 5000, 5000]
# Próbálkozások: 601000 | Gyűjtött minták: [2920, 2264, 5000, 5000]
# Próbálkozások: 602000 | Gyűjtött minták: [2925, 2269, 5000, 5000]
# Próbálkozások: 603000 | Gyűjtött minták: [2935, 2273, 5000, 5000]
# Próbálkozások: 604000 | Gyűjtött minták: [2940, 2274, 5000, 5000]
# Próbálkozások: 605000 | Gyűjtött minták: [2947, 2280, 5000, 5000]
# Próbálkozások: 606000 | Gyűjtött minták: [2952, 2283, 5000, 5000]
# Próbálkozások: 607000 | Gyűjtött minták: [2955, 2288, 5000, 5000]
# Próbálkozások: 608000 | Gyűjtött minták: [2960, 2290, 5000, 5000]
# Próbálkozások: 609000 | Gyűjtött minták: [2968, 2294, 5000, 5000]
# Próbálkozások: 610000 | Gyűjtött minták: [2972, 2299, 5000, 5000]
# Próbálkozások: 611000 | Gyűjtött minták: [2977, 2304, 5000, 5000]
# Próbálkozások: 612000 | Gyűjtött minták: [2981, 2306, 5000, 5000]
# Próbálkozások: 613000 | Gyűjtött minták: [2987, 2312, 5000, 5000]
# Próbálkozások: 614000 | Gyűjtött minták: [2991, 2316, 5000, 5000]
# Próbálkozások: 615000 | Gyűjtött minták: [2994, 2319, 5000, 5000]
# Próbálkozások: 616000 | Gyűjtött minták: [3001, 2321, 5000, 5000]
# Próbálkozások: 617000 | Gyűjtött minták: [3006, 2324, 5000, 5000]
# Próbálkozások: 618000 | Gyűjtött minták: [3011, 2327, 5000, 5000]
# Próbálkozások: 619000 | Gyűjtött minták: [3013, 2333, 5000, 5000]
# Próbálkozások: 620000 | Gyűjtött minták: [3021, 2337, 5000, 5000]
# Próbálkozások: 621000 | Gyűjtött minták: [3025, 2339, 5000, 5000]
# Próbálkozások: 622000 | Gyűjtött minták: [3031, 2342, 5000, 5000]
# Próbálkozások: 623000 | Gyűjtött minták: [3035, 2344, 5000, 5000]
# Próbálkozások: 624000 | Gyűjtött minták: [3040, 2348, 5000, 5000]
# Próbálkozások: 625000 | Gyűjtött minták: [3040, 2351, 5000, 5000]
# Próbálkozások: 626000 | Gyűjtött minták: [3048, 2360, 5000, 5000]
# Próbálkozások: 627000 | Gyűjtött minták: [3052, 2363, 5000, 5000]
# Próbálkozások: 628000 | Gyűjtött minták: [3056, 2365, 5000, 5000]
# Próbálkozások: 629000 | Gyűjtött minták: [3058, 2367, 5000, 5000]
# Próbálkozások: 630000 | Gyűjtött minták: [3067, 2369, 5000, 5000]
# Próbálkozások: 631000 | Gyűjtött minták: [3071, 2371, 5000, 5000]
# Próbálkozások: 632000 | Gyűjtött minták: [3079, 2374, 5000, 5000]
# Próbálkozások: 633000 | Gyűjtött minták: [3083, 2378, 5000, 5000]
# Próbálkozások: 634000 | Gyűjtött minták: [3088, 2380, 5000, 5000]
# Próbálkozások: 635000 | Gyűjtött minták: [3091, 2383, 5000, 5000]
# Próbálkozások: 636000 | Gyűjtött minták: [3097, 2384, 5000, 5000]
# Próbálkozások: 637000 | Gyűjtött minták: [3103, 2389, 5000, 5000]
# Próbálkozások: 638000 | Gyűjtött minták: [3108, 2395, 5000, 5000]
# Próbálkozások: 639000 | Gyűjtött minták: [3114, 2397, 5000, 5000]
# Próbálkozások: 640000 | Gyűjtött minták: [3119, 2400, 5000, 5000]
# Próbálkozások: 641000 | Gyűjtött minták: [3123, 2408, 5000, 5000]
# Próbálkozások: 642000 | Gyűjtött minták: [3130, 2413, 5000, 5000]
# Próbálkozások: 643000 | Gyűjtött minták: [3133, 2416, 5000, 5000]
# Próbálkozások: 644000 | Gyűjtött minták: [3143, 2419, 5000, 5000]
# Próbálkozások: 645000 | Gyűjtött minták: [3144, 2422, 5000, 5000]
# Próbálkozások: 646000 | Gyűjtött minták: [3148, 2423, 5000, 5000]
# Próbálkozások: 647000 | Gyűjtött minták: [3154, 2429, 5000, 5000]
# Próbálkozások: 648000 | Gyűjtött minták: [3159, 2435, 5000, 5000]
# Próbálkozások: 649000 | Gyűjtött minták: [3164, 2444, 5000, 5000]
# Próbálkozások: 650000 | Gyűjtött minták: [3170, 2447, 5000, 5000]
# Próbálkozások: 651000 | Gyűjtött minták: [3183, 2453, 5000, 5000]
# Próbálkozások: 652000 | Gyűjtött minták: [3187, 2459, 5000, 5000]
# Próbálkozások: 653000 | Gyűjtött minták: [3191, 2463, 5000, 5000]
# Próbálkozások: 654000 | Gyűjtött minták: [3196, 2470, 5000, 5000]
# Próbálkozások: 655000 | Gyűjtött minták: [3203, 2471, 5000, 5000]
# Próbálkozások: 656000 | Gyűjtött minták: [3210, 2474, 5000, 5000]
# Próbálkozások: 657000 | Gyűjtött minták: [3215, 2478, 5000, 5000]
# Próbálkozások: 658000 | Gyűjtött minták: [3220, 2480, 5000, 5000]
# Próbálkozások: 659000 | Gyűjtött minták: [3223, 2487, 5000, 5000]
# Próbálkozások: 660000 | Gyűjtött minták: [3229, 2490, 5000, 5000]
# Próbálkozások: 661000 | Gyűjtött minták: [3232, 2492, 5000, 5000]
# Próbálkozások: 662000 | Gyűjtött minták: [3234, 2499, 5000, 5000]
# Próbálkozások: 663000 | Gyűjtött minták: [3238, 2501, 5000, 5000]
# Próbálkozások: 664000 | Gyűjtött minták: [3244, 2506, 5000, 5000]
# Próbálkozások: 665000 | Gyűjtött minták: [3247, 2513, 5000, 5000]
# Próbálkozások: 666000 | Gyűjtött minták: [3251, 2516, 5000, 5000]
# Próbálkozások: 667000 | Gyűjtött minták: [3257, 2523, 5000, 5000]
# Próbálkozások: 668000 | Gyűjtött minták: [3267, 2527, 5000, 5000]
# Próbálkozások: 669000 | Gyűjtött minták: [3271, 2529, 5000, 5000]
# Próbálkozások: 670000 | Gyűjtött minták: [3277, 2530, 5000, 5000]
# Próbálkozások: 671000 | Gyűjtött minták: [3282, 2533, 5000, 5000]
# Próbálkozások: 672000 | Gyűjtött minták: [3287, 2538, 5000, 5000]
# Próbálkozások: 673000 | Gyűjtött minták: [3290, 2546, 5000, 5000]
# Próbálkozások: 674000 | Gyűjtött minták: [3295, 2550, 5000, 5000]
# Próbálkozások: 675000 | Gyűjtött minták: [3301, 2551, 5000, 5000]
# Próbálkozások: 676000 | Gyűjtött minták: [3308, 2558, 5000, 5000]
# Próbálkozások: 677000 | Gyűjtött minták: [3314, 2561, 5000, 5000]
# Próbálkozások: 678000 | Gyűjtött minták: [3323, 2564, 5000, 5000]
# Próbálkozások: 679000 | Gyűjtött minták: [3330, 2568, 5000, 5000]
# Próbálkozások: 680000 | Gyűjtött minták: [3339, 2571, 5000, 5000]
# Próbálkozások: 681000 | Gyűjtött minták: [3341, 2573, 5000, 5000]
# Próbálkozások: 682000 | Gyűjtött minták: [3344, 2576, 5000, 5000]
# Próbálkozások: 683000 | Gyűjtött minták: [3348, 2577, 5000, 5000]
# Próbálkozások: 684000 | Gyűjtött minták: [3353, 2578, 5000, 5000]
# Próbálkozások: 685000 | Gyűjtött minták: [3358, 2580, 5000, 5000]
# Próbálkozások: 686000 | Gyűjtött minták: [3364, 2587, 5000, 5000]
# Próbálkozások: 687000 | Gyűjtött minták: [3369, 2590, 5000, 5000]
# Próbálkozások: 688000 | Gyűjtött minták: [3373, 2595, 5000, 5000]
# Próbálkozások: 689000 | Gyűjtött minták: [3377, 2596, 5000, 5000]
# Próbálkozások: 690000 | Gyűjtött minták: [3382, 2598, 5000, 5000]
# Próbálkozások: 691000 | Gyűjtött minták: [3389, 2599, 5000, 5000]
# Próbálkozások: 692000 | Gyűjtött minták: [3396, 2600, 5000, 5000]
# Próbálkozások: 693000 | Gyűjtött minták: [3401, 2603, 5000, 5000]
# Próbálkozások: 694000 | Gyűjtött minták: [3407, 2605, 5000, 5000]
# Próbálkozások: 695000 | Gyűjtött minták: [3410, 2609, 5000, 5000]
# Próbálkozások: 696000 | Gyűjtött minták: [3416, 2615, 5000, 5000]
# Próbálkozások: 697000 | Gyűjtött minták: [3422, 2623, 5000, 5000]
# Próbálkozások: 698000 | Gyűjtött minták: [3427, 2625, 5000, 5000]
# Próbálkozások: 699000 | Gyűjtött minták: [3434, 2626, 5000, 5000]
# Próbálkozások: 700000 | Gyűjtött minták: [3437, 2631, 5000, 5000]
# Próbálkozások: 701000 | Gyűjtött minták: [3442, 2634, 5000, 5000]
# Próbálkozások: 702000 | Gyűjtött minták: [3445, 2636, 5000, 5000]
# Próbálkozások: 703000 | Gyűjtött minták: [3452, 2640, 5000, 5000]
# Próbálkozások: 704000 | Gyűjtött minták: [3454, 2645, 5000, 5000]
# Próbálkozások: 705000 | Gyűjtött minták: [3457, 2649, 5000, 5000]
# Próbálkozások: 706000 | Gyűjtött minták: [3462, 2649, 5000, 5000]
# Próbálkozások: 707000 | Gyűjtött minták: [3468, 2652, 5000, 5000]
# Próbálkozások: 708000 | Gyűjtött minták: [3475, 2661, 5000, 5000]
# Próbálkozások: 709000 | Gyűjtött minták: [3479, 2663, 5000, 5000]
# Próbálkozások: 710000 | Gyűjtött minták: [3485, 2670, 5000, 5000]
# Próbálkozások: 711000 | Gyűjtött minták: [3487, 2676, 5000, 5000]
# Próbálkozások: 712000 | Gyűjtött minták: [3492, 2679, 5000, 5000]
# Próbálkozások: 713000 | Gyűjtött minták: [3493, 2682, 5000, 5000]
# Próbálkozások: 714000 | Gyűjtött minták: [3504, 2683, 5000, 5000]
# Próbálkozások: 715000 | Gyűjtött minták: [3506, 2683, 5000, 5000]
# Próbálkozások: 716000 | Gyűjtött minták: [3512, 2686, 5000, 5000]
# Próbálkozások: 717000 | Gyűjtött minták: [3516, 2689, 5000, 5000]
# Próbálkozások: 718000 | Gyűjtött minták: [3519, 2694, 5000, 5000]
# Próbálkozások: 719000 | Gyűjtött minták: [3525, 2696, 5000, 5000]
# Próbálkozások: 720000 | Gyűjtött minták: [3533, 2697, 5000, 5000]
# Próbálkozások: 721000 | Gyűjtött minták: [3537, 2702, 5000, 5000]
# Próbálkozások: 722000 | Gyűjtött minták: [3539, 2708, 5000, 5000]
# Próbálkozások: 723000 | Gyűjtött minták: [3543, 2709, 5000, 5000]
# Próbálkozások: 724000 | Gyűjtött minták: [3547, 2714, 5000, 5000]
# Próbálkozások: 725000 | Gyűjtött minták: [3555, 2723, 5000, 5000]
# Próbálkozások: 726000 | Gyűjtött minták: [3559, 2724, 5000, 5000]
# Próbálkozások: 727000 | Gyűjtött minták: [3560, 2727, 5000, 5000]
# Próbálkozások: 728000 | Gyűjtött minták: [3566, 2729, 5000, 5000]
# Próbálkozások: 729000 | Gyűjtött minták: [3572, 2734, 5000, 5000]
# Próbálkozások: 730000 | Gyűjtött minták: [3577, 2741, 5000, 5000]
# Próbálkozások: 731000 | Gyűjtött minták: [3581, 2745, 5000, 5000]
# Próbálkozások: 732000 | Gyűjtött minták: [3586, 2747, 5000, 5000]
# Próbálkozások: 733000 | Gyűjtött minták: [3593, 2750, 5000, 5000]
# Próbálkozások: 734000 | Gyűjtött minták: [3596, 2753, 5000, 5000]
# Próbálkozások: 735000 | Gyűjtött minták: [3599, 2755, 5000, 5000]
# ...
# Próbálkozások: 1063000 | Gyűjtött minták: [5000, 4084, 5000, 5000]
# Próbálkozások: 1064000 | Gyűjtött minták: [5000, 4090, 5000, 5000]
# Próbálkozások: 1065000 | Gyűjtött minták: [5000, 4095, 5000, 5000]
# Próbálkozások: 1066000 | Gyűjtött minták: [5000, 4097, 5000, 5000]
# Próbálkozások: 1067000 | Gyűjtött minták: [5000, 4099, 5000, 5000]
# Próbálkozások: 1068000 | Gyűjtött minták: [5000, 4103, 5000, 5000]
# Próbálkozások: 1069000 | Gyűjtött minták: [5000, 4107, 5000, 5000]
# Próbálkozások: 1070000 | Gyűjtött minták: [5000, 4110, 5000, 5000]
# Próbálkozások: 1071000 | Gyűjtött minták: [5000, 4113, 5000, 5000]
# Próbálkozások: 1072000 | Gyűjtött minták: [5000, 4115, 5000, 5000]
# Próbálkozások: 1073000 | Gyűjtött minták: [5000, 4117, 5000, 5000]
# Próbálkozások: 1074000 | Gyűjtött minták: [5000, 4120, 5000, 5000]
# Próbálkozások: 1075000 | Gyűjtött minták: [5000, 4124, 5000, 5000]
# Próbálkozások: 1076000 | Gyűjtött minták: [5000, 4125, 5000, 5000]
# Próbálkozások: 1077000 | Gyűjtött minták: [5000, 4132, 5000, 5000]
# Próbálkozások: 1078000 | Gyűjtött minták: [5000, 4134, 5000, 5000]
# Próbálkozások: 1079000 | Gyűjtött minták: [5000, 4141, 5000, 5000]
# Próbálkozások: 1080000 | Gyűjtött minták: [5000, 4145, 5000, 5000]
# Próbálkozások: 1081000 | Gyűjtött minták: [5000, 4146, 5000, 5000]
# Próbálkozások: 1082000 | Gyűjtött minták: [5000, 4152, 5000, 5000]
# Próbálkozások: 1083000 | Gyűjtött minták: [5000, 4156, 5000, 5000]
# Próbálkozások: 1084000 | Gyűjtött minták: [5000, 4164, 5000, 5000]
# Próbálkozások: 1085000 | Gyűjtött minták: [5000, 4172, 5000, 5000]
# Próbálkozások: 1086000 | Gyűjtött minták: [5000, 4174, 5000, 5000]
# Próbálkozások: 1087000 | Gyűjtött minták: [5000, 4181, 5000, 5000]
# Próbálkozások: 1088000 | Gyűjtött minták: [5000, 4186, 5000, 5000]
# Próbálkozások: 1089000 | Gyűjtött minták: [5000, 4190, 5000, 5000]
# Próbálkozások: 1090000 | Gyűjtött minták: [5000, 4194, 5000, 5000]
# Próbálkozások: 1091000 | Gyűjtött minták: [5000, 4198, 5000, 5000]
# Próbálkozások: 1092000 | Gyűjtött minták: [5000, 4203, 5000, 5000]
# Próbálkozások: 1093000 | Gyűjtött minták: [5000, 4205, 5000, 5000]
# Próbálkozások: 1094000 | Gyűjtött minták: [5000, 4208, 5000, 5000]
# Próbálkozások: 1095000 | Gyűjtött minták: [5000, 4212, 5000, 5000]
# Próbálkozások: 1096000 | Gyűjtött minták: [5000, 4217, 5000, 5000]
# Próbálkozások: 1097000 | Gyűjtött minták: [5000, 4219, 5000, 5000]
# Próbálkozások: 1098000 | Gyűjtött minták: [5000, 4221, 5000, 5000]
# Próbálkozások: 1099000 | Gyűjtött minták: [5000, 4223, 5000, 5000]
# Próbálkozások: 1100000 | Gyűjtött minták: [5000, 4224, 5000, 5000]
# Próbálkozások: 1101000 | Gyűjtött minták: [5000, 4226, 5000, 5000]
# Próbálkozások: 1102000 | Gyűjtött minták: [5000, 4228, 5000, 5000]
# Próbálkozások: 1103000 | Gyűjtött minták: [5000, 4233, 5000, 5000]
# Próbálkozások: 1104000 | Gyűjtött minták: [5000, 4236, 5000, 5000]
# Próbálkozások: 1105000 | Gyűjtött minták: [5000, 4241, 5000, 5000]
# Próbálkozások: 1106000 | Gyűjtött minták: [5000, 4242, 5000, 5000]
# Próbálkozások: 1107000 | Gyűjtött minták: [5000, 4247, 5000, 5000]
# Próbálkozások: 1108000 | Gyűjtött minták: [5000, 4249, 5000, 5000]
# Próbálkozások: 1109000 | Gyűjtött minták: [5000, 4251, 5000, 5000]
# Próbálkozások: 1110000 | Gyűjtött minták: [5000, 4256, 5000, 5000]
# Próbálkozások: 1111000 | Gyűjtött minták: [5000, 4257, 5000, 5000]
# Próbálkozások: 1112000 | Gyűjtött minták: [5000, 4258, 5000, 5000]
# Próbálkozások: 1113000 | Gyűjtött minták: [5000, 4262, 5000, 5000]
# Próbálkozások: 1114000 | Gyűjtött minták: [5000, 4263, 5000, 5000]
# Próbálkozások: 1115000 | Gyűjtött minták: [5000, 4266, 5000, 5000]
# Próbálkozások: 1116000 | Gyűjtött minták: [5000, 4268, 5000, 5000]
# Próbálkozások: 1117000 | Gyűjtött minták: [5000, 4271, 5000, 5000]
# Próbálkozások: 1118000 | Gyűjtött minták: [5000, 4279, 5000, 5000]
# Próbálkozások: 1119000 | Gyűjtött minták: [5000, 4285, 5000, 5000]
# Próbálkozások: 1120000 | Gyűjtött minták: [5000, 4290, 5000, 5000]
# Próbálkozások: 1121000 | Gyűjtött minták: [5000, 4294, 5000, 5000]
# Próbálkozások: 1122000 | Gyűjtött minták: [5000, 4301, 5000, 5000]
# Próbálkozások: 1123000 | Gyűjtött minták: [5000, 4303, 5000, 5000]
# Próbálkozások: 1124000 | Gyűjtött minták: [5000, 4305, 5000, 5000]
# Próbálkozások: 1125000 | Gyűjtött minták: [5000, 4312, 5000, 5000]
# Próbálkozások: 1126000 | Gyűjtött minták: [5000, 4314, 5000, 5000]
# Próbálkozások: 1127000 | Gyűjtött minták: [5000, 4318, 5000, 5000]
# Próbálkozások: 1128000 | Gyűjtött minták: [5000, 4323, 5000, 5000]
# Próbálkozások: 1129000 | Gyűjtött minták: [5000, 4327, 5000, 5000]
# Próbálkozások: 1130000 | Gyűjtött minták: [5000, 4332, 5000, 5000]
# Próbálkozások: 1131000 | Gyűjtött minták: [5000, 4335, 5000, 5000]
# Próbálkozások: 1132000 | Gyűjtött minták: [5000, 4341, 5000, 5000]
# Próbálkozások: 1133000 | Gyűjtött minták: [5000, 4346, 5000, 5000]
# Próbálkozások: 1134000 | Gyűjtött minták: [5000, 4351, 5000, 5000]
# Próbálkozások: 1135000 | Gyűjtött minták: [5000, 4356, 5000, 5000]
# Próbálkozások: 1136000 | Gyűjtött minták: [5000, 4360, 5000, 5000]
# Próbálkozások: 1137000 | Gyűjtött minták: [5000, 4362, 5000, 5000]
# Próbálkozások: 1138000 | Gyűjtött minták: [5000, 4367, 5000, 5000]
# Próbálkozások: 1139000 | Gyűjtött minták: [5000, 4376, 5000, 5000]
# Próbálkozások: 1140000 | Gyűjtött minták: [5000, 4383, 5000, 5000]
# Próbálkozások: 1141000 | Gyűjtött minták: [5000, 4386, 5000, 5000]
# Próbálkozások: 1142000 | Gyűjtött minták: [5000, 4391, 5000, 5000]
# Próbálkozások: 1143000 | Gyűjtött minták: [5000, 4395, 5000, 5000]
# Próbálkozások: 1144000 | Gyűjtött minták: [5000, 4399, 5000, 5000]
# Próbálkozások: 1145000 | Gyűjtött minták: [5000, 4406, 5000, 5000]
# Próbálkozások: 1146000 | Gyűjtött minták: [5000, 4413, 5000, 5000]
# Próbálkozások: 1147000 | Gyűjtött minták: [5000, 4415, 5000, 5000]
# Próbálkozások: 1148000 | Gyűjtött minták: [5000, 4419, 5000, 5000]
# Próbálkozások: 1149000 | Gyűjtött minták: [5000, 4423, 5000, 5000]
# Próbálkozások: 1150000 | Gyűjtött minták: [5000, 4428, 5000, 5000]
# Próbálkozások: 1151000 | Gyűjtött minták: [5000, 4432, 5000, 5000]
# Próbálkozások: 1152000 | Gyűjtött minták: [5000, 4437, 5000, 5000]
# Próbálkozások: 1153000 | Gyűjtött minták: [5000, 4440, 5000, 5000]
# Próbálkozások: 1154000 | Gyűjtött minták: [5000, 4446, 5000, 5000]
# Próbálkozások: 1155000 | Gyűjtött minták: [5000, 4453, 5000, 5000]
# Próbálkozások: 1156000 | Gyűjtött minták: [5000, 4457, 5000, 5000]
# Próbálkozások: 1157000 | Gyűjtött minták: [5000, 4459, 5000, 5000]
# Próbálkozások: 1158000 | Gyűjtött minták: [5000, 4465, 5000, 5000]
# Próbálkozások: 1159000 | Gyűjtött minták: [5000, 4465, 5000, 5000]
# Próbálkozások: 1160000 | Gyűjtött minták: [5000, 4467, 5000, 5000]
# Próbálkozások: 1161000 | Gyűjtött minták: [5000, 4471, 5000, 5000]
# Próbálkozások: 1162000 | Gyűjtött minták: [5000, 4472, 5000, 5000]
# Próbálkozások: 1163000 | Gyűjtött minták: [5000, 4476, 5000, 5000]
# Próbálkozások: 1164000 | Gyűjtött minták: [5000, 4478, 5000, 5000]
# Próbálkozások: 1165000 | Gyűjtött minták: [5000, 4485, 5000, 5000]
# Próbálkozások: 1166000 | Gyűjtött minták: [5000, 4490, 5000, 5000]
# Próbálkozások: 1167000 | Gyűjtött minták: [5000, 4494, 5000, 5000]
# Próbálkozások: 1168000 | Gyűjtött minták: [5000, 4497, 5000, 5000]
# Próbálkozások: 1169000 | Gyűjtött minták: [5000, 4500, 5000, 5000]
# Próbálkozások: 1170000 | Gyűjtött minták: [5000, 4505, 5000, 5000]
# Próbálkozások: 1171000 | Gyűjtött minták: [5000, 4513, 5000, 5000]
# Próbálkozások: 1172000 | Gyűjtött minták: [5000, 4517, 5000, 5000]
# Próbálkozások: 1173000 | Gyűjtött minták: [5000, 4522, 5000, 5000]
# Próbálkozások: 1174000 | Gyűjtött minták: [5000, 4525, 5000, 5000]
# Próbálkozások: 1175000 | Gyűjtött minták: [5000, 4529, 5000, 5000]
# Próbálkozások: 1176000 | Gyűjtött minták: [5000, 4533, 5000, 5000]
# Próbálkozások: 1177000 | Gyűjtött minták: [5000, 4535, 5000, 5000]
# Próbálkozások: 1178000 | Gyűjtött minták: [5000, 4539, 5000, 5000]
# Próbálkozások: 1179000 | Gyűjtött minták: [5000, 4546, 5000, 5000]
# Próbálkozások: 1180000 | Gyűjtött minták: [5000, 4551, 5000, 5000]
# Próbálkozások: 1181000 | Gyűjtött minták: [5000, 4553, 5000, 5000]
# Próbálkozások: 1182000 | Gyűjtött minták: [5000, 4556, 5000, 5000]
# Próbálkozások: 1183000 | Gyűjtött minták: [5000, 4560, 5000, 5000]
# Próbálkozások: 1184000 | Gyűjtött minták: [5000, 4560, 5000, 5000]
# Próbálkozások: 1185000 | Gyűjtött minták: [5000, 4568, 5000, 5000]
# Próbálkozások: 1186000 | Gyűjtött minták: [5000, 4573, 5000, 5000]
# Próbálkozások: 1187000 | Gyűjtött minták: [5000, 4576, 5000, 5000]
# Próbálkozások: 1188000 | Gyűjtött minták: [5000, 4580, 5000, 5000]
# Próbálkozások: 1189000 | Gyűjtött minták: [5000, 4583, 5000, 5000]
# Próbálkozások: 1190000 | Gyűjtött minták: [5000, 4586, 5000, 5000]
# Próbálkozások: 1191000 | Gyűjtött minták: [5000, 4588, 5000, 5000]
# Próbálkozások: 1192000 | Gyűjtött minták: [5000, 4590, 5000, 5000]
# Próbálkozások: 1193000 | Gyűjtött minták: [5000, 4594, 5000, 5000]
# Próbálkozások: 1194000 | Gyűjtött minták: [5000, 4595, 5000, 5000]
# Próbálkozások: 1195000 | Gyűjtött minták: [5000, 4596, 5000, 5000]
# Próbálkozások: 1196000 | Gyűjtött minták: [5000, 4600, 5000, 5000]
# Próbálkozások: 1197000 | Gyűjtött minták: [5000, 4604, 5000, 5000]
# Próbálkozások: 1198000 | Gyűjtött minták: [5000, 4611, 5000, 5000]
# Próbálkozások: 1199000 | Gyűjtött minták: [5000, 4615, 5000, 5000]
# Próbálkozások: 1200000 | Gyűjtött minták: [5000, 4619, 5000, 5000]
# Próbálkozások: 1201000 | Gyűjtött minták: [5000, 4622, 5000, 5000]
# Próbálkozások: 1202000 | Gyűjtött minták: [5000, 4625, 5000, 5000]
# Próbálkozások: 1203000 | Gyűjtött minták: [5000, 4630, 5000, 5000]
# Próbálkozások: 1204000 | Gyűjtött minták: [5000, 4635, 5000, 5000]
# Próbálkozások: 1205000 | Gyűjtött minták: [5000, 4640, 5000, 5000]
# Próbálkozások: 1206000 | Gyűjtött minták: [5000, 4644, 5000, 5000]
# Próbálkozások: 1207000 | Gyűjtött minták: [5000, 4648, 5000, 5000]
# Próbálkozások: 1208000 | Gyűjtött minták: [5000, 4651, 5000, 5000]
# Próbálkozások: 1209000 | Gyűjtött minták: [5000, 4655, 5000, 5000]
# Próbálkozások: 1210000 | Gyűjtött minták: [5000, 4657, 5000, 5000]
# Próbálkozások: 1211000 | Gyűjtött minták: [5000, 4663, 5000, 5000]
# Próbálkozások: 1212000 | Gyűjtött minták: [5000, 4663, 5000, 5000]
# Próbálkozások: 1213000 | Gyűjtött minták: [5000, 4668, 5000, 5000]
# Próbálkozások: 1214000 | Gyűjtött minták: [5000, 4668, 5000, 5000]
# Próbálkozások: 1215000 | Gyűjtött minták: [5000, 4673, 5000, 5000]
# Próbálkozások: 1216000 | Gyűjtött minták: [5000, 4678, 5000, 5000]
# Próbálkozások: 1217000 | Gyűjtött minták: [5000, 4683, 5000, 5000]
# Próbálkozások: 1218000 | Gyűjtött minták: [5000, 4690, 5000, 5000]
# Próbálkozások: 1219000 | Gyűjtött minták: [5000, 4697, 5000, 5000]
# Próbálkozások: 1220000 | Gyűjtött minták: [5000, 4703, 5000, 5000]
# Próbálkozások: 1221000 | Gyűjtött minták: [5000, 4709, 5000, 5000]
# Próbálkozások: 1222000 | Gyűjtött minták: [5000, 4714, 5000, 5000]
# Próbálkozások: 1223000 | Gyűjtött minták: [5000, 4723, 5000, 5000]
# Próbálkozások: 1224000 | Gyűjtött minták: [5000, 4724, 5000, 5000]
# Próbálkozások: 1225000 | Gyűjtött minták: [5000, 4732, 5000, 5000]
# Próbálkozások: 1226000 | Gyűjtött minták: [5000, 4733, 5000, 5000]
# Próbálkozások: 1227000 | Gyűjtött minták: [5000, 4737, 5000, 5000]
# Próbálkozások: 1228000 | Gyűjtött minták: [5000, 4742, 5000, 5000]
# Próbálkozások: 1229000 | Gyűjtött minták: [5000, 4745, 5000, 5000]
# Próbálkozások: 1230000 | Gyűjtött minták: [5000, 4748, 5000, 5000]
# Próbálkozások: 1231000 | Gyűjtött minták: [5000, 4748, 5000, 5000]
# Próbálkozások: 1232000 | Gyűjtött minták: [5000, 4750, 5000, 5000]
# Próbálkozások: 1233000 | Gyűjtött minták: [5000, 4754, 5000, 5000]
# Próbálkozások: 1234000 | Gyűjtött minták: [5000, 4761, 5000, 5000]
# Próbálkozások: 1235000 | Gyűjtött minták: [5000, 4766, 5000, 5000]
# Próbálkozások: 1236000 | Gyűjtött minták: [5000, 4770, 5000, 5000]
# Próbálkozások: 1237000 | Gyűjtött minták: [5000, 4774, 5000, 5000]
# Próbálkozások: 1238000 | Gyűjtött minták: [5000, 4779, 5000, 5000]
# Próbálkozások: 1239000 | Gyűjtött minták: [5000, 4784, 5000, 5000]
# Próbálkozások: 1240000 | Gyűjtött minták: [5000, 4791, 5000, 5000]
# Próbálkozások: 1241000 | Gyűjtött minták: [5000, 4795, 5000, 5000]
# Próbálkozások: 1242000 | Gyűjtött minták: [5000, 4803, 5000, 5000]
# Próbálkozások: 1243000 | Gyűjtött minták: [5000, 4806, 5000, 5000]
# Próbálkozások: 1244000 | Gyűjtött minták: [5000, 4811, 5000, 5000]
# Próbálkozások: 1245000 | Gyűjtött minták: [5000, 4815, 5000, 5000]
# Próbálkozások: 1246000 | Gyűjtött minták: [5000, 4817, 5000, 5000]
# Próbálkozások: 1247000 | Gyűjtött minták: [5000, 4825, 5000, 5000]
# Próbálkozások: 1248000 | Gyűjtött minták: [5000, 4826, 5000, 5000]
# Próbálkozások: 1249000 | Gyűjtött minták: [5000, 4830, 5000, 5000]
# Próbálkozások: 1250000 | Gyűjtött minták: [5000, 4832, 5000, 5000]
# Próbálkozások: 1251000 | Gyűjtött minták: [5000, 4833, 5000, 5000]
# Próbálkozások: 1252000 | Gyűjtött minták: [5000, 4836, 5000, 5000]
# Próbálkozások: 1253000 | Gyűjtött minták: [5000, 4838, 5000, 5000]
# Próbálkozások: 1254000 | Gyűjtött minták: [5000, 4841, 5000, 5000]
# Próbálkozások: 1255000 | Gyűjtött minták: [5000, 4844, 5000, 5000]
# Próbálkozások: 1256000 | Gyűjtött minták: [5000, 4847, 5000, 5000]
# Próbálkozások: 1257000 | Gyűjtött minták: [5000, 4852, 5000, 5000]
# Próbálkozások: 1258000 | Gyűjtött minták: [5000, 4854, 5000, 5000]
# Próbálkozások: 1259000 | Gyűjtött minták: [5000, 4856, 5000, 5000]
# Próbálkozások: 1260000 | Gyűjtött minták: [5000, 4859, 5000, 5000]
# Próbálkozások: 1261000 | Gyűjtött minták: [5000, 4860, 5000, 5000]
# Próbálkozások: 1262000 | Gyűjtött minták: [5000, 4863, 5000, 5000]
# Próbálkozások: 1263000 | Gyűjtött minták: [5000, 4865, 5000, 5000]
# Próbálkozások: 1264000 | Gyűjtött minták: [5000, 4871, 5000, 5000]
# Próbálkozások: 1265000 | Gyűjtött minták: [5000, 4878, 5000, 5000]
# Próbálkozások: 1266000 | Gyűjtött minták: [5000, 4882, 5000, 5000]
# Próbálkozások: 1267000 | Gyűjtött minták: [5000, 4883, 5000, 5000]
# Próbálkozások: 1268000 | Gyűjtött minták: [5000, 4886, 5000, 5000]
# Próbálkozások: 1269000 | Gyűjtött minták: [5000, 4889, 5000, 5000]
# Próbálkozások: 1270000 | Gyűjtött minták: [5000, 4892, 5000, 5000]
# Próbálkozások: 1271000 | Gyűjtött minták: [5000, 4902, 5000, 5000]
# Próbálkozások: 1272000 | Gyűjtött minták: [5000, 4908, 5000, 5000]
# Próbálkozások: 1273000 | Gyűjtött minták: [5000, 4911, 5000, 5000]
# Próbálkozások: 1274000 | Gyűjtött minták: [5000, 4913, 5000, 5000]
# Próbálkozások: 1275000 | Gyűjtött minták: [5000, 4916, 5000, 5000]
# Próbálkozások: 1276000 | Gyűjtött minták: [5000, 4920, 5000, 5000]
# Próbálkozások: 1277000 | Gyűjtött minták: [5000, 4926, 5000, 5000]
# Próbálkozások: 1278000 | Gyűjtött minták: [5000, 4929, 5000, 5000]
# Próbálkozások: 1279000 | Gyűjtött minták: [5000, 4931, 5000, 5000]
# Próbálkozások: 1280000 | Gyűjtött minták: [5000, 4936, 5000, 5000]
# Próbálkozások: 1281000 | Gyűjtött minták: [5000, 4939, 5000, 5000]
# Próbálkozások: 1282000 | Gyűjtött minták: [5000, 4943, 5000, 5000]
# Próbálkozások: 1283000 | Gyűjtött minták: [5000, 4944, 5000, 5000]
# Próbálkozások: 1284000 | Gyűjtött minták: [5000, 4945, 5000, 5000]
# Próbálkozások: 1285000 | Gyűjtött minták: [5000, 4951, 5000, 5000]
# Próbálkozások: 1286000 | Gyűjtött minták: [5000, 4954, 5000, 5000]
# Próbálkozások: 1287000 | Gyűjtött minták: [5000, 4957, 5000, 5000]
# Próbálkozások: 1288000 | Gyűjtött minták: [5000, 4961, 5000, 5000]
# Próbálkozások: 1289000 | Gyűjtött minták: [5000, 4963, 5000, 5000]
# Próbálkozások: 1290000 | Gyűjtött minták: [5000, 4969, 5000, 5000]
# Próbálkozások: 1291000 | Gyűjtött minták: [5000, 4974, 5000, 5000]
# Próbálkozások: 1292000 | Gyűjtött minták: [5000, 4975, 5000, 5000]
# Próbálkozások: 1293000 | Gyűjtött minták: [5000, 4977, 5000, 5000]
# Próbálkozások: 1294000 | Gyűjtött minták: [5000, 4979, 5000, 5000]
# Próbálkozások: 1295000 | Gyűjtött minták: [5000, 4982, 5000, 5000]
# Próbálkozások: 1296000 | Gyűjtött minták: [5000, 4985, 5000, 5000]
# Próbálkozások: 1297000 | Gyűjtött minták: [5000, 4993, 5000, 5000]
# Próbálkozások: 1298000 | Gyűjtött minták: [5000, 4996, 5000, 5000]
# Próbálkozások: 1299000 | Gyűjtött minták: [5000, 4999, 5000, 5000]
# Próbálkozások: 1300000 | Gyűjtött minták: [5000, 4999, 5000, 5000]
